# %% [markdown]
# <a href="https://colab.research.google.com/github/dkisselev-zz/mmc-pipeline/blob/main/Microbiome_Articles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Microbiome Metadata Crisis project
# Sam Degregori, PhD
# SD IRACDA Fellow, Pediatrics
# University of California San Diego
# samdegregori@gmail.com
#
# Dmitry Kisselev Code

# %% [markdown]
# ## IMPORTS & INITIAL SETUP

# %%
# !pip install pymed google-generativeai boto3
# Out:
# Collecting pymed
#   Downloading pymed-0.8.9-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.11/dist-packages (0.8.5)
# Collecting boto3
#   Downloading boto3-1.38.43-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.11/dist-packages (from pymed) (2.32.3)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.172.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.11.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.14.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Collecting botocore<1.39.0,>=1.38.43 (from boto3)
#   Downloading botocore-1.38.43-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3)
#   Downloading s3transfer-0.13.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.39.0,>=1.38.43->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.39.0,>=1.38.43->boto3) (2.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->pymed) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->pymed) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->pymed) (2025.6.15)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.4.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.73.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.39.0,>=1.38.43->boto3) (1.17.0)
# Downloading pymed-0.8.9-py3-none-any.whl (9.6 kB)
# Downloading boto3-1.38.43-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 2.8 MB/s eta 0:00:00
# Downloading botocore-1.38.43-py3-none-any.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 90.4 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.13.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: jmespath, pymed, botocore, s3transfer, boto3
# Successfully installed boto3-1.38.43 botocore-1.38.43 jmespath-1.0.1 pymed-0.8.9 s3transfer-0.13.0

# %%
from pymed import PubMed
import pandas as pd
import google.generativeai as genai
from google.colab import userdata
import requests
import time
import re
import xml.etree.ElementTree as ET
import boto3
from botocore.client import Config
from botocore import UNSIGNED
from botocore.exceptions import NoCredentialsError, ClientError

# %% [markdown]
# ## PARAMETERS & CONFIGURATION

# %%
# --- Search Parameters ---
ENVIRONMENT = "oral"

# 1. Define your environments with a list of related keywords.
#    Using [Title/Abstract] (or [tiab]) makes the search highly relevant.
ENVIRONMENTS = {
    "oral": [
        '"oral"[tiab]', '"saliva"[tiab]', '"salivary"[tiab]', '"dental plaque"[tiab]',
        '"gingival"[tiab]', '"periodontal"[tiab]', '"subgingival"[tiab]', '"supragingival"[tiab]'
    ],
    "gut": [
        '"gut"[tiab]', '"gastrointestinal"[tiab]', '"intestinal"[tiab]',
        '"fecal"[tiab]', '"feces"[tiab]', '"colonic"[tiab]'
    ],
    "skin": [
        '"skin"[tiab]', '"cutaneous"[tiab]'
    ]
}

# 2. Define the core concepts related to the microbiome.
MICROBIOME_CONCEPTS = [
    '"microbiome"[Title/Abstract]', '"microbiota"[Title/Abstract]',
    '"microflora"[Title/Abstract]', '"dysbiosis"[Title/Abstract]'
]

# 3. Select your target environment for this run.
TARGET_ENVIRONMENT = "oral"

# 4. Programmatically build the final search query.
# This creates the (A OR B OR C) structure for each part of the query.
environment_query = "(" + " OR ".join(ENVIRONMENTS[TARGET_ENVIRONMENT]) + ")"
microbiome_query = "(" + " OR ".join(MICROBIOME_CONCEPTS) + ")"

# 5. Assemble the final, complete search term.
SEARCH_TERM = (
    f"({environment_query} AND {microbiome_query}) "
    "AND (ffrft[Filter]) "
    "NOT (Review[PT] OR Editorial[PT] OR Letter[PT] OR Comment[PT] OR Case Reports[PT])"
)

# SEARCH_TERM = f"{ENVIRONMENT} microbiome NOT (Review[Publication Type])"
MAX_RESULTS = 100

# --- LLM Configuration ---
LLM_MODEL = "gemini-1.5-flash" # gemini-2.5-flash

# --- Google API Configuration ---
try:
    API_KEY = userdata.get('GOOGLE_API_KEY')
    genai.configure(api_key=API_KEY)
except (ValueError, FileNotFoundError):
    raise ValueError("GOOGLE_API_KEY not found in Colab secrets. Please add it.")

# --- LLM Prompts ---
# Centralized prompts
PROMPTS = {
    "get_country": (
        "Based on the following metadata from a scientific article, suggest the most likely country of publication or the primary country "
        "associated with this research. Provide ONLY the country name.\n\nMetadata:\n{metadata_text}"
    ),
    "predict_article_type": (
        "Analyze the following article information to determine if it is a Review or Original Research. "
        "Provide a brief one-sentence rationale for your choice, followed by the classification. "
        "Use this format exactly:\n"
        "Rationale: [Your one-sentence reasoning]\n"
        "Classification: [Review or Original Research or Unknown]\n\n"
        "Information:\n{llm_input_text}"
    ),
    "predict_sequencing_type": (
        "Analyze the text below from a scientific article to identify all high-throughput sequencing methods used Classify the method(s) into one or more of the following categories:\n"
        "- **16S:** ...\n"
        "- **Other:** ... such as rpoB, rpoC, cpn60, or ITS...\n"
        "- **Shotgun:** ...\n"
        "- **Unknown:** ...\n\n"
        "Instructions:\n"
        "1. List all methods you identify, separated by commas.\n"
        "2. If you identify 'Other', specify the gene in parentheses (e.g., 'Other (rpoB)').\n"
        "3. Extract a short quote, if there is no method identified use None value for it...\n\n"
        "Respond in the following format exactly:\n"
        "Primary Method(s): [Method1, Method2, ...]\n"
        "Supporting Quote:\n\n"
        "Text Snippet:\n"
        "{text_snippet}\n"
    ),
    "find_accession_code": (
        "Analyze the following text from a scientific article. Your task is to find sequencing data accession codes "
        "(e.g., PRJNA..., SRP..., SRA..., etc.) or a URL pointing to the data.\n\n"
        "Respond with ONLY the accession code(s) or the URL. If you find multiple, separate them with commas. "
        "If you find none, respond with 'NO RELEVANT INFORMATION'.\n\nText:\n{text_snippet}"
    ),
    "classify_environment": (
        "Analyze the following text from a scientific paper. Your task is to classify the primary microbiome environment being studied into ONE of the following categories.\n\n"
        "Allowed Categories:\n"
        "- Gastrointestinal Tract (e.g., gut, intestinal, fecal, colonic)\n"
        "- Oral Cavity (e.g., saliva, dental, periodontal, buccal)\n"
        "- Respiratory System (e.g., lung, nasal, airway)\n"
        "- Urogenital System (e.g., vaginal, urinary)\n"
        "- Dermal / Cutaneous (e.g., skin)\n"
        "- Ocular (e.g., eye)\n"
        "- Blood\n"
        "- Breast Milk\n"
        "- Cardiac (e.g., heart)\n"
        "- Wound\n"
        "- Tumor\n"
        "- Aquatic (e.g., marine, freshwater)\n"
        "- Terrestrial (e.g., soil, environmental)\n"
        "- Plant-Associated\n"
        "- Invertebrate-Associated\n"
        "- Multiple (if the study clearly focuses on two or more distinct environments, e.g., both gut and skin)\n"
        "- Not Sure (if you cannot determine the environment from the text\n\n"
        "Respond with ONLY the category name from the list above.\n\n"
        "Text Snippet:\n"
        "{text_snippet}\n"
  ),
}

# %% [markdown]
# ## Utility classes and methods

# %%
class ArticleProcessor:
    """
    A class to process and enrich PubMed article data using LLMs and AWS S3.
    """
    def __init__(self, gemini_model_name, s3_config=None):
        """
        Initializes the processor with the Gemini model and an S3 client.
        """
        self.model = genai.GenerativeModel(gemini_model_name)
        if s3_config is None:
            s3_config = Config(signature_version=UNSIGNED)
        self.s3_client = boto3.client('s3', config=s3_config)

        # Pre-compile regex for accession number check
        self.accession_pattern = re.compile(r'(PRJNA\d+|PRJEB\d+|SRP\d+|ERP\d+|DRP\d+|SRA\d+)', re.IGNORECASE)

        # Add a dictionary for standardizing country names.
        self.COUNTRY_SYNONYMS = {
            'USA': 'United States',
            'U.S.A': 'United States',
            'U.S.A.': 'United States',
            'U.S.': 'United States',
            'UK': 'United Kingdom',
            'U.K.': 'United Kingdom',
            'P.R.C.': 'China',
            'PRC': 'China'
        }

        # Define the keywords for major, top-level sections of a paper.
        # This list will be used to determine the true boundaries of a section.
        self.MAJOR_SECTION_KEYWORDS = [
            'introduction', 'background',
            'methods', 'materials and methods', 'experimental procedures', 'study design',
            'results', 'discussion', 'conclusion',
            'ethics', 'acknowledgements', 'abbreviations',
            'author contributions', 'competing interests',
            'funding', 'references', 'supplementary'
        ]

    def _call_gemini(self, prompt, retries=3, delay=5):
        """
        Private method for all Gemini API calls.
        Handles API calls, response parsing, and basic error handling/retries.
        """
        for attempt in range(retries):
            try:
                response = self.model.generate_content(prompt)
                return response.text.strip()
            except Exception as e:
                print(f"Error calling Gemini API (Attempt {attempt + 1}/{retries}): {e}")
                if attempt < retries - 1:
                    time.sleep(delay)
                else:
                    return "LLM Error"

    def classify_environment(self, abstract, full_text_content=None):
        """
        ## NEW: Uses the LLM to classify the microbiome environment based on the abstract and introduction.
        Returns one of the predefined categories.
        """
        # --- Step 1: Prepare the context snippet ---
        context_parts = []
        if abstract:
            context_parts.append(f"ABSTRACT:\n{abstract}")

        # Use the beginning of the full text as a proxy for the introduction
        if full_text_content:
            # Taking the first 2500 chars of the body is a good heuristic for the intro
            intro_snippet = full_text_content[:2500]
            context_parts.append(f"\n\nINTRODUCTION (FROM FULL TEXT):\n{intro_snippet}")

        if not context_parts:
            return "Not Sure"

        text_snippet = "\n".join(context_parts)

        # --- Step 2: Define allowed categories and call the LLM ---
        allowed_categories = {
            'Gastrointestinal Tract', 'Oral Cavity', 'Respiratory System', 'Urogenital System',
            'Dermal / Cutaneous', 'Ocular', 'Blood', 'Breast Milk', 'Cardiac', 'Wound', 'Tumor', 'Aquatic',
            'Terrestrial', 'Plant-Associated', 'Invertebrate-Associated', 'Multiple', 'Not Sure'
        }

        prompt = PROMPTS["classify_environment"].format(text_snippet=text_snippet)
        llm_response = self._call_gemini(prompt).strip()

        # --- Step 3: Validate the response ---
        # If the LLM returns one of the exact category names, use it.
        if llm_response in allowed_categories:
            return llm_response
        else:
            # If the LLM fails to follow instructions, default to "Not Sure".
            print(f"Warning: LLM returned a non-standard environment class: '{llm_response}'. Defaulting to 'Not Sure'.")
            return "Not Sure"

    # --- Methods for Country Extraction ---
    def get_country_from_metadata(self, pubmed_id):
        """
        Fetches article metadata, uses an LLM to determine the country,
        and standardizes the result.
        """
        efetch_url = f"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id={pubmed_id}&retmode=xml"
        try:
            response = requests.get(efetch_url)
            response.raise_for_status()
            root = ET.fromstring(response.content)

            # Extract affiliations and journal info
            affiliations = " ".join([elem.text for elem in root.findall('.//AffiliationInfo/Affiliation') if elem.text])
            journal_titles = " ".join([elem.text for elem in root.findall('.//Journal/Title') if elem.text])
            metadata_text = f"{affiliations} {journal_titles}".strip()

            if not metadata_text:
                return "No Metadata"

            prompt = PROMPTS["get_country"].format(metadata_text=metadata_text)
            country_from_llm = self._call_gemini(prompt)

            # Clean up potential LLM additions like "Country: "
            cleaned_country = country_from_llm.replace("Suggested Country:", "").replace("Country:", "").strip()

            # --- Standardization Step ---
            # Use .upper() for a case-insensitive lookup in our synonym dictionary.
            # .get() returns the standardized name if found, otherwise it returns the
            # original cleaned_country name as a default.
            standardized_country = self.COUNTRY_SYNONYMS.get(cleaned_country.upper(), cleaned_country)

            return standardized_country

        except requests.exceptions.RequestException as e:
            print(f"Error fetching metadata for {pubmed_id}: {e}")
            return "Request Error"
        except ET.ParseError as e:
            print(f"Error parsing XML for {pubmed_id}: {e}")
            return "XML Error"

    # --- Methods for Article Classification ---
    def predict_article_type(self, title, abstract, publication_types):
        """
        Now takes clean data as direct arguments.
        Classifies an article and provides a confidence level.
        """
        # --- Tier 1: High-Confidence Rule-Based Check ---
        pub_types = {pt.lower() for pt in publication_types}
        REVIEW_TYPES = {'review', 'systematic review', 'meta-analysis'}
        # Simplified the original research types for broader applicability
        ORIGINAL_RESEARCH_TYPES = {'clinical trial', 'randomized controlled trial', 'comparative study'}

        if REVIEW_TYPES.intersection(pub_types):
            return 'Review', 'High'
        if ORIGINAL_RESEARCH_TYPES.intersection(pub_types):
             return 'Original Research', 'High'

        # --- Tier 2: LLM Analysis ---
        input_parts = []
        if title: input_parts.append(f"Title: {title}")
        if abstract: input_parts.append(f"Abstract: {abstract}")

        if not input_parts: return "Unknown", "Low"

        # ... (The rest of the method logic is the same) ...
        llm_input_text = "\n".join(input_parts)
        prompt = PROMPTS["predict_article_type"].format(llm_input_text=llm_input_text)
        response_text = self._call_gemini(prompt)

        llm_classification = "Unknown"
        for line in response_text.split('\n'):
            if line.lower().startswith("classification:"):
                llm_classification = line.split(":", 1)[1].strip()

        confidence = "Medium"
        text_to_search = llm_input_text.lower()

        if 'review' in llm_classification.lower():
            llm_classification = 'Review'
            if any(kw in text_to_search for kw in ['a review', 'systematic review', 'meta-analysis', 'narrative review']):
                confidence = 'High'
        elif 'original research' in llm_classification.lower():
            llm_classification = 'Original Research'
            if any(kw in text_to_search for kw in ['methods', 'results', 'we enrolled', 'we analyzed', 'our study', 'we conducted']):
                confidence = 'High'
        else:
            llm_classification = 'Unknown'
            confidence = 'Low'

        return llm_classification, confidence

    def _parse_sequencing_response(self, response_text):
        """
        # Parses the structured response for sequencing type and
        # cleans the output to handle more LLM variations (e.g., "None") and ensure data quality.
        """
        if "LLM Error" in response_text:
            return "Prediction Error", ""

        # --- Step 1: Parse the raw response from the LLM ---
        seq_type = "Unknown"
        quote = "No supporting quote found"

        for line in response_text.split('\n'):
            clean_line = line.lower().strip()
            if clean_line.startswith("primary method(s):"):
                seq_type = line.split(":", 1)[1].strip()
            elif clean_line.startswith("supporting quote:"):
                quote = line.split(":", 1)[1].strip()

        # --- Step 2: NEW Cleanup and Validation Logic ---

        # Define "failure" keywords. Added 'none' to handle this new case.
        failure_keywords = ["unknown", "error", "no abstract", "none"]
        # Check if the returned type is a failure type. Use strip() to handle whitespace.
        is_type_failure = seq_type.strip().lower() in failure_keywords

        # Define unhelpful, placeholder quotes.
        placeholder_quotes = [
            "no supporting quote found",
            "not specified",
            "not mentioned",
            "n/a",
            "none",
            "[...]",
            "[]",
            ""
        ]
        is_quote_placeholder = quote.strip().lower() in placeholder_quotes

        # --- Final Decision Logic ---
        # If the type indicates a failure, standardize the output completely.
        if is_type_failure:
            seq_type = "Unknown"  # Standardize the type to our internal value.
            quote = ""            # Always clear the quote on failure.

        # If the type is valid but the quote is just a placeholder, clear the quote.
        elif is_quote_placeholder:
            quote = ""

        return seq_type, quote

    def predict_sequencing_type_advanced(self, abstract, keywords, full_text_content=None):
        """
        Now takes clean abstract and keywords as direct arguments.
        Predicts sequencing type using a tiered strategy.
        """
        # --- Tier 1: Use Abstract and Keywords ---
        print("Tier 1: Analyzing abstract and keywords...")
        context_parts = []
        if abstract:
            context_parts.append(f"Abstract:\n{abstract}")
        if keywords:
            context_parts.append(f"Keywords:\n{', '.join(keywords)}")

        if not context_parts:
            # If no abstract/keywords, proceed directly to full text search
            print("Tier 1 skipped: No abstract or keywords available.")
        else:
            initial_context = "\n\n".join(context_parts)
            prompt = PROMPTS["predict_sequencing_type"].format(text_snippet=initial_context)
            response_text = self._call_gemini(prompt)
            seq_type, seq_quote = self._parse_sequencing_response(response_text)

            # If we get a clear answer, we're done.
            if "unknown" not in seq_type.lower():
                return seq_type, seq_quote

        # --- Tier 2: Search Full Text ---
        if not full_text_content:
            print("Tier 2 skipped: No full text available.")
            return "Unknown", "" # Return a definite unknown if no other info is available

        print("Tier 2: Abstract/keywords inconclusive. Analyzing 'Methods' section of full text...")

        methods_keywords = ['method', 'materials and methods', 'experimental procedures', 'study design']
        methods_section = self._extract_section_text(full_text_content, methods_keywords)

        if not methods_section:
            print("Tier 2 failed: Could not find 'Methods' section.")
            return "Unknown", ""

        prompt = PROMPTS["predict_sequencing_type"].format(text_snippet=methods_section)
        response_text = self._call_gemini(prompt)

        return self._parse_sequencing_response(response_text)

    # --- S3 and Accession Code Search ---
    def get_s3_article_text(self, pmc_id):
        """
        Checks for a PMC article in public S3 buckets and returns its content if found.
        """
        if not pmc_id or not str(pmc_id).strip():
            return None, "No PMC ID"

        # The bucket is always the same, but the prefix within the bucket changes.
        bucket_name = 'pmc-oa-opendata'
        key_prefixes = ['oa_comm/txt/all/', 'oa_noncomm/txt/all/']

        object_key = f"{pmc_id}.txt"

        for prefix in key_prefixes:
            full_key = prefix + object_key
            try:
                # Use head_object for a fast check
                self.s3_client.head_object(Bucket=bucket_name, Key=full_key)
                # If it exists, get the full object
                response = self.s3_client.get_object(Bucket=bucket_name, Key=full_key)
                return response['Body'].read().decode('utf-8'), "Found"
            except ClientError as e:
                if e.response['Error']['Code'] == '404':
                    continue # Not in this prefix, try the next one
                else:
                    print(f"S3 ClientError for {pmc_id}: {e}")
                    return None, "S3 Error"
            except Exception as e:
                print(f"Unexpected error for {pmc_id}: {e}")
                return None, "S3 Error"

        return None, "Not Found in S3"

    def _map_all_sections(self, full_text):
        """
        Simple and robust single-line heading finder.
        It no longer looks for numbers, only for lines that look like headings.
        """
        section_map = []
        # This regex identifies single lines that look like headings (reasonable length, starts with a capital).
        heading_pattern = re.compile(r"^\s*([A-Z][^\n]{4,100})$", re.MULTILINE)

        for match in heading_pattern.finditer(full_text):
            title = match.group(1).strip()

            # Simple filter for common non-headings
            if title.upper() in ['STRENGTHS AND LIMITATIONS OF THIS STUDY']:
                continue

            section_map.append({
                'title': title,
                'start': match.start()
            })
        return section_map

    def _extract_section_text(self, full_text, heading_keywords):
        """
        The Definitive Semantic Solution.
        Uses a list of "Major Section Keywords" to determine the true boundaries of a section,
        correctly including all of its subsections.
        """
        if not full_text:
            return None

        section_map = self._map_all_sections(full_text)
        if not section_map:
            return None

        longest_section_text = ""

        # Find all candidate sections that match our target keywords (e.g., "methods")
        for i, start_section in enumerate(section_map):
            # Check if the title of the section is one we're looking for
            if any(keyword in start_section['title'].lower() for keyword in heading_keywords):

                start_pos = start_section['start']
                end_pos = len(full_text) # Default to the end of the document

                # Look ahead to find the boundary
                for j in range(i + 1, len(section_map)):
                    next_section_title = section_map[j]['title'].lower()

                    # The boundary is the NEXT major section.
                    # We check if any of our major keywords are in the next section's title.
                    if any(major_keyword in next_section_title for major_keyword in self.MAJOR_SECTION_KEYWORDS):
                        end_pos = section_map[j]['start']
                        break # Found the boundary, stop looking ahead

                current_section_text = full_text[start_pos:end_pos]

                # We still keep the "longest section" logic to handle cases where "Methods"
                # might appear in both the abstract and the body.
                if len(current_section_text) > len(longest_section_text):
                    longest_section_text = current_section_text

        # Use a hard limit to avoid sending excessively large snippets to the LLM
        MAX_SNIPPET_LENGTH = 25000
        final_text = longest_section_text[:MAX_SNIPPET_LENGTH]

        return final_text if final_text else None

    def find_accession_codes(self, text_content):
        """
        Finds accession codes using a tiered, intelligent search strategy.
        1. Tries fast regex search on the whole text.
        2. Tries to find and use the 'Data Availability' section.
        3. Falls back to other sections like 'Methods'.
        4. As a last resort, uses a generic snippet.
        """
        if not text_content:
            return "", "No Text Provided"

        # --- Step 1: Fast Regex Search (Most Efficient) ---
        regex_matches = self.accession_pattern.findall(text_content)
        if regex_matches:
            # Return unique, sorted codes
            return ", ".join(sorted(list(set(regex_matches)))), "Found by Regex"

        # --- Step 2: Intelligent Tiered Section Search for LLM ---
        snippet = None
        find_method_note = "Not Found" # Default note

        # Define the sections to search for, in order of priority
        search_tiers = {
            "Data Availability Statement": [
                'data availability', 'availability of data', 'data and material availability',
                'data access', 'deposition of data'
            ],
            "Supplementary Material": [
                'supplementary material', 'supporting information'
            ],
            "Methods Section": [
                'method', 'materials and methods', 'experimental procedures'
            ]
        }

        for section_name, keywords in search_tiers.items():
            section_text = self._extract_section_text(text_content, keywords)
            if section_text:
                snippet = section_text
                find_method_note = f"Found by LLM in {section_name}"
                print(f"Found potential section '{section_name}'. Using it for LLM search.")
                break # Found a section, stop searching

        # --- Step 3: Fallback to Generic Snippet if no section was found ---
        if not snippet:
            print("No specific section found. Falling back to generic snippet for LLM search.")
            find_method_note = "Found by LLM in Generic Snippet"
            # Use a slightly larger snippet than before as a last resort
            if len(text_content) > 8000:
                snippet = text_content[:4000] + "\n...\n" + text_content[-4000:]
            else:
                snippet = text_content

        # --- Step 4: Call LLM with the best available snippet ---
        prompt = PROMPTS["find_accession_code"].format(text_snippet=snippet)
        llm_result = self._call_gemini(prompt)

        if "NO RELEVANT INFORMATION" in llm_result.upper() or "LLM ERROR" in llm_result:
            return "", "Not Found by LLM"
        else:
            # Return the LLM's finding and the method we used to find it
            return llm_result, find_method_note

    # --- NCBI SRA Methods ---
    def get_sra_sample_details(self, accession_code):
        """
        Queries the NCBI SRA database to validate an accession number
        and retrieve metadata about sample/run titles.

        Args:
            accession_code (str): A single SRA accession code (e.g., 'PRJEB76625').

        Returns:
            A tuple containing:
            - sra_name_example (str): An example title of a run.
            - differentiates_samples (str): 'Yes' if titles are different, 'No' if they are the same.
                                            Returns 'N/A' for errors or single-sample projects.
        """
        if not accession_code or not str(accession_code).strip():
            return "N/A", "N/A"

        # NCBI E-utilities base URL
        base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/"

        # Take the first accession code if multiple are listed
        main_accession = accession_code.split(',')[0].strip()

        try:
            # Use esearch to validate and get UIDs
            esearch_url = f"{base_url}esearch.fcgi?db=sra&term={main_accession}"
            # NCBI rate limits: max 3 requests/sec without API key
            # TODO: Use NCBI API Key instead
            time.sleep(0.4)
            response = requests.get(esearch_url)
            response.raise_for_status()

            root = ET.fromstring(response.content)
            id_list = [elem.text for elem in root.findall('.//Id')]

            if not id_list:
                print(f"SRA Validation Failed: Accession {main_accession} not found.")
                return "Invalid Accession", "N/A"

            # Use efetch to get full metadata for the UIDs
            efetch_url = f"{base_url}efetch.fcgi?db=sra&id={','.join(id_list)}&retmode=xml"
            time.sleep(0.4)
            response = requests.get(efetch_url)
            response.raise_for_status()

            sra_root = ET.fromstring(response.content)

            # Parse the XML to find all run titles
            # The title for each run is usually located at EXPERIMENT_PACKAGE/RUN_SET/RUN/TITLE
            all_titles = [elem.text for elem in sra_root.findall('.//RUN/TITLE') if elem.text]

            if not all_titles:
                # Sometimes titles are at the Experiment level
                all_titles = [elem.text for elem in sra_root.findall('.//EXPERIMENT/TITLE') if elem.text]

            if not all_titles:
                print(f"SRA Metadata Warning: No run titles found for {main_accession}.")
                return "No Titles Found", "N/A"

            # Analyze titles and return results
            sra_name_example = all_titles[0]

            # Check if there are multiple runs to compare
            if len(all_titles) <= 1:
                differentiates_samples = "N/A (Single Run)"
            else:
                # Use a set to find unique titles. If len > 1, they are different.
                unique_titles = set(all_titles)
                differentiates_samples = "Yes" if len(unique_titles) > 1 else "No"

            return sra_name_example, differentiates_samples

        except requests.exceptions.RequestException as e:
            print(f"NCBI API request error for {main_accession}: {e}")
            return "API Request Error", "N/A"
        except ET.ParseError as e:
            print(f"NCBI XML parse error for {main_accession}: {e}")
            return "XML Parse Error", "N/A"
        except Exception as e:
            print(f"An unexpected error occurred for {main_accession}: {e}")
            return "Unexpected Error", "N/A"

    # --- Static Utility Methods ---
    @staticmethod
    def find_pmc_id_in_xml(article_xml_element):
        """Finds the PMC ID from the article's XML element."""
        if not isinstance(article_xml_element, ET.Element): return None
        try:
            for article_id in article_xml_element.findall('.//ArticleId'):
                if article_id.get('IdType') == 'pmc':
                    return article_id.text
            return None
        except Exception as e:
            print(f"Error searching for PMC ID: {e}")
            return None

    @staticmethod
    def get_clean_article_title_from_xml(article_xml_element):
        """Extracts and cleans the article title from the XML."""
        if not isinstance(article_xml_element, ET.Element): return "N/A"
        try:
            title_element = article_xml_element.find('.//ArticleTitle')
            if title_element is not None:
                # Reconstruct text content, handling tags like <i>, <b>
                raw_title = "".join(title_element.itertext())
                # Clean up whitespace
                clean_title = re.sub(r'\s+', ' ', raw_title).strip()
                return clean_title
            return "N/A"
        except Exception as e:
            print(f"Error extracting title from XML: {e}")
            return "Error"

    @staticmethod
    def get_publication_year(article_xml_element):
        """
        Robustly finds the publication year by checking multiple XML locations.
        Checks for 'pubmed', 'entrez', 'JournalIssue', and 'accepted' dates in order of priority.

        Args:
            article_xml_element (xml.etree.ElementTree.Element): The root XML element for the article.

        Returns:
            A string representing the 4-digit year, or "N/A" if not found.
        """
        if not isinstance(article_xml_element, ET.Element):
            return "N/A"

        # Define XPath expressions in our desired order of preference
        xpath_priority_list = [
            ".//PubMedPubDate[@PubStatus='pubmed']",
            ".//PubMedPubDate[@PubStatus='entrez']",
            ".//Journal/JournalIssue/PubDate",
            ".//PubMedPubDate[@PubStatus='accepted']",
        ]

        for xpath in xpath_priority_list:
            date_element = article_xml_element.find(xpath)
            if date_element is not None:
                # The 'Year' tag is a direct child in all these cases
                year_element = date_element.find('Year')
                if year_element is not None and year_element.text:
                    # Found a valid year, return it and stop searching
                    return year_element.text.strip()

        # If the loop completes without finding a year in any of the prioritized locations
        return "N/A"

    @staticmethod
    def get_clean_abstract_from_xml(article_xml_element):
        """
        Robustly extracts the full abstract from XML.
        Handles multiple <AbstractText> sections and inline formatting tags (e.g., <i>).
        It preserves the section labels (e.g., BACKGROUND, METHODS) for better context.

        Args:
            article_xml_element (xml.etree.ElementTree.Element): The root XML element for the article.

        Returns:
            A single string containing the full, cleaned abstract, or an empty string if not found.
        """
        if not isinstance(article_xml_element, ET.Element):
            return ""

        abstract_element = article_xml_element.find('.//Abstract')
        if abstract_element is None:
            return ""

        abstract_parts = []
        # Iterate through all <AbstractText> nodes within the <Abstract> tag
        for abstract_text_node in abstract_element.findall('AbstractText'):
            # Get the section label (e.g., "BACKGROUND") if it exists
            label = abstract_text_node.get('Label', '').strip()

            # .itertext() correctly extracts all text, including from child tags like <i>
            text_content = "".join(abstract_text_node.itertext()).strip()

            if label:
                # Format with the label for better readability and context for the LLM
                abstract_parts.append(f"{label.upper()}: {text_content}")
            else:
                # If there's no label, just append the text
                abstract_parts.append(text_content)

        # Join all parts with a double newline to separate the sections
        return "\n\n".join(abstract_parts)

# %%
|# pyMed provides all found Pub ID in the metadata which creates a problem when
# url is created from that information

def clean_study_link(link):
    if isinstance(link, str) and link.strip():
        # Split the string by newline characters
        parts = link.split('\n')
        # The first part should contain the base URL and the first ID
        first_part = parts[0]
        # Ensure it ends with a '/'
        if not first_part.endswith('/'):
            first_part += '/'
        return first_part
    else:
        return "" # Return empty string for non-string or empty values

# %% [markdown]
# ## MAIN EXECUTION SCRIPT

# %%
# --- Initialization ---
print("Initializing PubMed Searcher and Article Processor...")
pubmed = PubMed(tool="PubMedSearcher", email="dmitry756@gmail.com")
processor = ArticleProcessor(gemini_model_name=LLM_MODEL)
# Out:
# Initializing PubMed Searcher and Article Processor...

# %%
# --- Perform Search ---
print(f"Searching PubMed for: '{SEARCH_TERM}'...")
results = pubmed.query(SEARCH_TERM, max_results=MAX_RESULTS)
articles = list(results)
print(f"Found {len(articles)} articles.")
# Out:
# Searching PubMed for: '(("oral"[tiab] OR "saliva"[tiab] OR "salivary"[tiab] OR "dental plaque"[tiab] OR "gingival"[tiab] OR "periodontal"[tiab] OR "subgingival"[tiab] OR "supragingival"[tiab]) AND ("microbiome"[Title/Abstract] OR "microbiota"[Title/Abstract] OR "microflora"[Title/Abstract] OR "dysbiosis"[Title/Abstract])) AND (ffrft[Filter]) NOT (Review[PT] OR Editorial[PT] OR Letter[PT] OR Comment[PT] OR Case Reports[PT])'...
# Found 100 articles.

# %%
print("\n--- Step 1: Building initial DataFrame from PubMed metadata ---")
initial_data = []
for article in articles[0:15]:
    pmid = article.pubmed_id.split()[0]
    pub_date = processor.get_publication_year(article.xml)
    authors = [a.get('lastname', '') for a in article.authors if a.get('lastname')]
    author_string = f"{''.join(authors[:2])}{pub_date}"

    initial_data.append({
        'PMID': pmid,
        'author1author2Year': author_string,
        'StudyTitle': processor.get_clean_article_title_from_xml(article.xml),
        'Year': pub_date,
        'PMC': processor.find_pmc_id_in_xml(article.xml),
        # We will enrich the rest of the data in the next step
    })
df = pd.DataFrame(initial_data)
# Out:
# --- Step 1: Building initial DataFrame from PubMed metadata ---

# %%
# --- Step 2: Enrich DataFrame with API Calls (LLM, S3, NCBI) ---
# This  consolidated loop handles all processing that requires external calls or full text.
# This is more efficient as S3 content is fetched only ONCE per article.
print("\n--- Step 2: Enriching DataFrame with API calls ---")

enrichment_results = []
for index, row in df.iterrows():
    article = articles[index] # Get the original pymed object using the index
    pmid = row['PMID']
    pmc_id = row['PMC']
    print(f"\nProcessing article {index + 1}/{len(df)} (PMID: {pmid})...")

    # --- Get Clean Data Once ---
    clean_title = df.loc[index, 'StudyTitle'] # We already have this from Step 1
    clean_abstract = processor.get_clean_abstract_from_xml(article.xml)
    keywords = article.keywords if hasattr(article, 'keywords') else []

    # --- S3 and Full-Text Processing ---
    text_content, s3_status = processor.get_s3_article_text(pmc_id)

    # --- Run ALL content-based analyses ---
    # Classify environment based on abstract and full text
    classified_environment = processor.classify_environment(clean_abstract, text_content)

    seq_type, seq_quote = processor.predict_sequencing_type_advanced(clean_abstract, keywords, text_content)
    accession_code, find_method = processor.find_accession_codes(text_content)

    # --- Other API Calls ---
    time.sleep(1) # Rate limit
    country = processor.get_country_from_metadata(pmid)
    time.sleep(1)

    # Pass clean data to this function as well
    pub_type = article.publication_types if hasattr(article, 'publication_types') else []
    article_type, type_confidence = processor.predict_article_type(clean_title, clean_abstract, pub_type)

    # --- SRA Lookup ---
    sra_example, sra_differentiates = processor.get_sra_sample_details(accession_code)

    enrichment_results.append({
        'PMID': pmid,
        'Environment': classified_environment,
        'Country': country,
        'Type': article_type,
        'TypeConfidence': type_confidence,
        'SequencingType': seq_type,
        'SequencingQuote': seq_quote,
        'S3_Status': s3_status,
        'AccessionCode': accession_code,
        'AccessionFindMethod': find_method,
        'SRAnameExample': sra_example,
        'SRAnamePresentAndDifferentiatesSamples': sra_differentiates,
        'Abstract': clean_abstract # Save the clean abstract to the DataFrame
    })

# Merge the enrichment results back into the main DataFrame
enrichment_df = pd.DataFrame(enrichment_results)
df = pd.merge(df, enrichment_df, on='PMID')
# Out:
# --- Step 2: Enriching DataFrame with API calls ---
#
# Processing article 1/15 (PMID: 40544684)...
# Tier 1: Analyzing abstract and keywords...
# Tier 2 skipped: No full text available.
#
# Processing article 2/15 (PMID: 40541100)...
# Tier 1: Analyzing abstract and keywords...
# Tier 2 skipped: No full text available.
#
# Processing article 3/15 (PMID: 40540389)...
# Tier 1: Analyzing abstract and keywords...
# Tier 2 skipped: No full text available.
#
# Processing article 4/15 (PMID: 40538752)...
# Tier 1: Analyzing abstract and keywords...
# Tier 2: Abstract/keywords inconclusive. Analyzing 'Methods' section of full text...
# Tier 2 failed: Could not find 'Methods' section.
# Found potential section 'Data Availability Statement'. Using it for LLM search.
# SRA Validation Failed: Accession https://doi.org/10.1016/j.mtbio.2025.101945 not found.
#
# Processing article 5/15 (PMID: 40535541)...
# Tier 1: Analyzing abstract and keywords...
# Found potential section 'Data Availability Statement'. Using it for LLM search.
#
# Processing article 6/15 (PMID: 40535082)...
# Tier 1: Analyzing abstract and keywords...
# Found potential section 'Methods Section'. Using it for LLM search.
#
# Processing article 7/15 (PMID: 40533209)...
# Tier 1: Analyzing abstract and keywords...
# Tier 2: Abstract/keywords inconclusive. Analyzing 'Methods' section of full text...
# Found potential section 'Supplementary Material'. Using it for LLM search.
#
# Processing article 8/15 (PMID: 40533160)...
# Tier 1: Analyzing abstract and keywords...
# Tier 2 skipped: No full text available.
#
# Processing article 9/15 (PMID: 40533070)...
# Tier 1: Analyzing abstract and keywords...
# Tier 2 skipped: No full text available.
#
# Processing article 10/15 (PMID: 40532026)...
# Tier 1: Analyzing abstract and keywords...
# Found potential section 'Data Availability Statement'. Using it for LLM search.
# SRA Validation Failed: Accession GSE293354 not found.
#
# Processing article 11/15 (PMID: 40529585)...
# Tier 1: Analyzing abstract and keywords...
# Tier 2: Abstract/keywords inconclusive. Analyzing 'Methods' section of full text...
# Found potential section 'Data Availability Statement'. Using it for LLM search.
#
# Processing article 12/15 (PMID: 40529499)...
# Tier 1: Analyzing abstract and keywords...
#
# Processing article 13/15 (PMID: 40529420)...
# Tier 1: Analyzing abstract and keywords...
# Tier 2: Abstract/keywords inconclusive. Analyzing 'Methods' section of full text...
# Found potential section 'Data Availability Statement'. Using it for LLM search.
#
# Processing article 14/15 (PMID: 40528838)...
# Tier 1: Analyzing abstract and keywords...
# Tier 2: Abstract/keywords inconclusive. Analyzing 'Methods' section of full text...
# Tier 2 failed: Could not find 'Methods' section.
# Found potential section 'Data Availability Statement'. Using it for LLM search.
#
# Processing article 15/15 (PMID: 40528272)...
# Tier 1: Analyzing abstract and keywords...

# %%
# --- Step 3: Final Cleanup & Display ---
print("\n--- Step 3: Finalizing DataFrame ---")
final_columns = [
    'author1author2Year',
    'YourName', 'Environment',
    'StudyLink', 'StudyTitle', 'Year', 'Country',
    'Type', 'TypeConfidence',
    'SequencingType', 'SequencingQuote', 'AccessionCode', 'AccessionFindMethod',
    'SRAnameExample', 'SRAnamePresentAndDifferentiatesSamples', 'S3_Status',
    'PMC', 'PMID'
]
# Add any missing columns and set default values
for col in final_columns:
    if col not in df.columns:
        df[col] = ''
df['StudyLink'] = df['PMID'].apply(lambda pmid: f'https://pubmed.ncbi.nlm.nih.gov/{pmid}/')
# Fill in other static columns
df['YourName'] = 'DmitryKisselev'
# df['Environment'] = ENVIRONMENT

# Reorder columns and display
df = df[final_columns]
display(df)
# Out:
# --- Step 3: Finalizing DataFrame ---
#                      author1author2Year        YourName  \
# 0                    EckermannKlein2025  DmitryKisselev
# 1                           TangMao2025  DmitryKisselev
# 2                           HuangLu2025  DmitryKisselev
# 3                          LeiCheng2025  DmitryKisselev
# 4                   Kato-KogoeTsuda2025  DmitryKisselev
# 5                            WangHu2025  DmitryKisselev
# 6         Stolberg-MathieuMikkelsen2025  DmitryKisselev
# 7                NakashimaShinohara2025  DmitryKisselev
# 8                       RussellCain2025  DmitryKisselev
# 9                   MatsumotoHitaka2025  DmitryKisselev
# 10                            LinWu2025  DmitryKisselev
# 11                        ZhangWang2025  DmitryKisselev
# 12                  StarckBlumfield2025  DmitryKisselev
# 13                           SunFan2025  DmitryKisselev
# 14  Guitart-MatasVera-Ponce de León2025  DmitryKisselev
#
#                Environment                                  StudyLink  \
# 0              Oral Cavity  https://pubmed.ncbi.nlm.nih.gov/40544684/
# 1   Gastrointestinal Tract  https://pubmed.ncbi.nlm.nih.gov/40541100/
# 2   Gastrointestinal Tract  https://pubmed.ncbi.nlm.nih.gov/40540389/
# 3   Gastrointestinal Tract  https://pubmed.ncbi.nlm.nih.gov/40538752/
# 4              Oral Cavity  https://pubmed.ncbi.nlm.nih.gov/40535541/
# 5              Oral Cavity  https://pubmed.ncbi.nlm.nih.gov/40535082/
# 6   Gastrointestinal Tract  https://pubmed.ncbi.nlm.nih.gov/40533209/
# 7   Gastrointestinal Tract  https://pubmed.ncbi.nlm.nih.gov/40533160/
# 8                 Multiple  https://pubmed.ncbi.nlm.nih.gov/40533070/
# 9                 Multiple  https://pubmed.ncbi.nlm.nih.gov/40532026/
# 10  Gastrointestinal Tract  https://pubmed.ncbi.nlm.nih.gov/40529585/
# 11  Gastrointestinal Tract  https://pubmed.ncbi.nlm.nih.gov/40529499/
# 12                Multiple  https://pubmed.ncbi.nlm.nih.gov/40529420/
# 13  Gastrointestinal Tract  https://pubmed.ncbi.nlm.nih.gov/40528838/
# 14  Gastrointestinal Tract  https://pubmed.ncbi.nlm.nih.gov/40528272/
#
#                                            StudyTitle  Year        Country  \
# 0   Probiotics-embedded polymer films for oral hea...  2025        Germany
# 1   Cecal microbiota transplantation enhances calc...  2025          China
# 2   Dietary Selenium Deficiency Accelerates the On...  2025  United States
# 3   Microalgal-enhanced cerium oxide nanotherapeut...  2025          China
# 4   Salivary microbiota and IgA responses are diff...  2025          Japan
# 5   Oral microbiome and risk of lung cancer: resul...  2025          China
# 6   The MOTILITY Mother-Child Cohort: a Danish pro...  2025        Denmark
# 7   Phocaeicola dorei and Phocaeicola vulgatus Pro...  2025          Japan
# 8   Collecting at-Home Biometric Measures for Long...  2025  United States
# 9   Exploration of predictive factors based on ora...  2025          Japan
# 10  Oral administration of Lactiplantibacillus pla...  2025         Taiwan
# 11  Role of gut microbiota in bempedoic acid again...  2025          China
# 12  A1 protein free milk benefits mood and subject...  2025      Australia
# 13  Synergistic ROS/enzyme dual-responsive oral dr...  2025          China
# 14  Multi-omics surveillance of antimicrobial resi...  2025          Spain
#
#                  Type TypeConfidence                  SequencingType  \
# 0   Original Research         Medium                         Unknown
# 1   Original Research           High                         Unknown
# 2   Original Research           High                         Unknown
# 3   Original Research         Medium                         Unknown
# 4   Original Research           High                    16S, IgA-seq
# 5   Original Research           High                         Shotgun
# 6   Original Research           High                  [16S, Shotgun]
# 7   Original Research           High                         Unknown
# 8   Original Research           High                         Unknown
# 9   Original Research           High                             16S
# 10  Original Research           High                         Unknown
# 11  Original Research           High                    16S, Shotgun
# 12  Original Research           High                         Shotgun
# 13  Original Research         Medium                         Unknown
# 14  Original Research           High  [Shotgun, Metatranscriptomics]
#
#                                       SequencingQuote  \
# 0
# 1
# 2
# 3
# 4   "Further, 16S rRNA metagenomic analysis was pe...
# 5   "Summary statistics for the oral microbiomes w...
# 6   "The primary outcome will be a characterisatio...
# 7
# 8
# 9   "Oral saliva and stool samples were analyzed f...
# 10
# 11  "Moreover, 16S rRNA sequencing of gut microbio...
# 12  "DNA extraction was performed using the DNeasy...
# 13
# 14  "Here, two sequencing approaches, shotgun meta...
#
#                                   AccessionCode  \
# 0
# 1
# 2
# 3   https://doi.org/10.1016/j.mtbio.2025.101945
# 4
# 5
# 6
# 7
# 8
# 9                                     GSE293354
# 10
# 11                                    SRP563800
# 12
# 13
# 14                                 PRJNA1010706
#
#                             AccessionFindMethod         SRAnameExample  \
# 0                              No Text Provided                    N/A
# 1                              No Text Provided                    N/A
# 2                              No Text Provided                    N/A
# 3   Found by LLM in Data Availability Statement      Invalid Accession
# 4                              Not Found by LLM                    N/A
# 5                              Not Found by LLM                    N/A
# 6                              Not Found by LLM                    N/A
# 7                              No Text Provided                    N/A
# 8                              No Text Provided                    N/A
# 9   Found by LLM in Data Availability Statement      Invalid Accession
# 10                             Not Found by LLM                    N/A
# 11                               Found by Regex  sequences of bacteria
# 12                             Not Found by LLM                    N/A
# 13                             Not Found by LLM                    N/A
# 14                               Found by Regex          100_804_G5_V1
#
#    SRAnamePresentAndDifferentiatesSamples  S3_Status          PMC      PMID
# 0                                     N/A  No PMC ID         None  40544684
# 1                                     N/A  No PMC ID         None  40541100
# 2                                     N/A  No PMC ID         None  40540389
# 3                                     N/A      Found  PMC12178715  40538752
# 4                                     N/A      Found  PMC12174153  40535541
# 5                                     N/A      Found  PMC12170216  40535082
# 6                                     N/A      Found  PMC12182182  40533209
# 7                                     N/A  No PMC ID         None  40533160
# 8                                     N/A  No PMC ID         None  40533070
# 9                                     N/A      Found  PMC12176287  40532026
# 10                                    N/A      Found  PMC12170587  40529585
# 11                                     No      Found  PMC12170663  40529499
# 12                                    N/A      Found  PMC12170308  40529420
# 13                                    N/A      Found  PMC12173668  40528838
# 14                                    Yes      Found  PMC12172226  40528272

# %% [markdown]
# ## Fix data

# %%
indx=5
seq = predict_sequencing_type_and_quote(df['Abstract'][indx])
df.at[indx,'SequencingType']=seq[0]
df.at[indx,'SequencingQuote']=seq[1]

# %%
for index, row in df.iterrows():
    title = get_clean_article_title_from_xml(articles[index].xml)
    df.at[index,'StudyTitle']=title

# %% [markdown]
# ## Debug and Test

# %%
df
# Out:
#         PMID        author1author2Year  \
# 0   40544684        EckermannKlein2025
# 1   40544638             ZhangChen2025
# 2   40543709             BrehmWang2025
# 3   40542437  Duran-PinedoSolbiati2025
# 4   40541836         PostolacheSha2025
# 5   40541100               TangMao2025
# 6   40540389               HuangLu2025
# 7   40539790         AdamsCampbell2025
# 8   40539731                LeeKim2025
# 9   40538752              LeiCheng2025
# 10  40538224                SunXin2025
# 11  40535541       Kato-KogoeTsuda2025
# 12  40535082                WangHu2025
# 13  40534416               WangWei2025
# 14  40533160    NakashimaShinohara2025
#
#                                            StudyTitle  Year          PMC  \
# 0   Probiotics-embedded polymer films for oral hea...  2025         None
# 1   Computationally-guided multifunctional nanopla...  2025         None
# 2   Inflammatory markers and microbiome dysbiosis ...  2025         None
# 3   Correction: Longitudinal host-microbiome dynam...  2025  PMC12180239
# 4   Porphyromonas gingivalis capsular K1 serotype ...  2025         None
# 5   Cecal microbiota transplantation enhances calc...  2025         None
# 6   Dietary Selenium Deficiency Accelerates the On...  2025         None
# 7   Legionella pneumophila type II secretome revea...  2025         None
# 8   Nasal Microbial Community Shifts Following Tre...  2025         None
# 9   Microalgal-enhanced cerium oxide nanotherapeut...  2025  PMC12178715
# 10  Self-Assembled Photothermal Particles Boost Sy...  2025         None
# 11  Salivary microbiota and IgA responses are diff...  2025  PMC12174153
# 12  Oral microbiome and risk of lung cancer: resul...  2025  PMC12170216
# 13  Oral Microbiota Dysbiosis Initiated by Chronic...  2025         None
# 14  Phocaeicola dorei and Phocaeicola vulgatus Pro...  2025         None
#
#           Country               Type        SequencingType  \
# 0         Germany  Original Research         Other/Unknown
# 1           China  Original Research
# 2   United States  Original Research     16S rRNA Amplicon
# 3   United States             Review  No Abstract/Keywords
# 4   United States  Original Research                  None
# 5           China  Original Research         Other/Unknown
# 6   United States  Original Research                  None
# 7   United States            Unknown                  None
# 8     South Korea  Original Research     16S rRNA Amplicon
# 9           China  Original Research                  None
# 10          China  Original Research         Other/Unknown
# 11          Japan  Original Research     16S rRNA Amplicon
# 12          China  Original Research  Shotgun Metagenomics
# 13          China  Original Research     16S rRNA Amplicon
# 14          Japan  Original Research                  None
#
#                                       SequencingQuote  S3_Status  \
# 0                                                      No PMC ID
# 1                                                      No PMC ID
# 2   "...analyzed both the oral and gut microbiome ...  No PMC ID
# 3                                                          Found
# 4                                                      No PMC ID
# 5                                                      No PMC ID
# 6                                                      No PMC ID
# 7                                                      No PMC ID
# 8   "16S rRNA‐based sequencing, chronic rhinitis, ...  No PMC ID
# 9                                                          Found
# 10                                                     No PMC ID
# 11  "16S rRNA metagenomic analysis was performed t...      Found
# 12  "Summary statistics for the oral microbiomes w...      Found
# 13  "oral microbiome characterization was performe...  No PMC ID
# 14                                                     No PMC ID
#
#    AccessionCode AccessionFindMethod SRAnameExample  \
# 0                   No Text Provided            N/A
# 1                   No Text Provided            N/A
# 2                   No Text Provided            N/A
# 3                   Not Found by LLM            N/A
# 4                   No Text Provided            N/A
# 5                   No Text Provided            N/A
# 6                   No Text Provided            N/A
# 7                   No Text Provided            N/A
# 8                   No Text Provided            N/A
# 9                   Not Found by LLM            N/A
# 10                  No Text Provided            N/A
# 11                  Not Found by LLM            N/A
# 12                  Not Found by LLM            N/A
# 13                  No Text Provided            N/A
# 14                  No Text Provided            N/A
#
#    SRAnamePresentAndDifferentiatesSamples
# 0                                     N/A
# 1                                     N/A
# 2                                     N/A
# 3                                     N/A
# 4                                     N/A
# 5                                     N/A
# 6                                     N/A
# 7                                     N/A
# 8                                     N/A
# 9                                     N/A
# 10                                    N/A
# 11                                    N/A
# 12                                    N/A
# 13                                    N/A
# 14                                    N/A

# %%
# List available models
for m in genai.list_models():
  print(m.name)
# Out:
# models/embedding-gecko-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-2.5-pro-exp-03-25
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-04-17
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-preview-04-17-thinking
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/embedding-001
# models/text-embedding-004
# models/gemini-embedding-exp-03-07
# models/gemini-embedding-exp
# models/aqa
# models/imagen-3.0-generate-002
# models/veo-2.0-generate-001
# models/gemini-2.5-flash-preview-native-audio-dialog
# models/gemini-2.5-flash-preview-native-audio-dialog-rai-v3
# models/gemini-2.5-flash-exp-native-audio-thinking-dialog
# models/gemini-2.0-flash-live-001

# %%
print(ET.tostring(articles[1].xml, encoding='unicode'))
# Out:
# <PubmedArticle><MedlineCitation Status="Publisher" Owner="NLM"><PMID Version="1">40552124</PMID><DateRevised><Year>2025</Year><Month>06</Month><Day>24</Day></DateRevised><Article PubModel="Electronic-eCollection"><Journal><ISSN IssnType="Electronic">2235-2988</ISSN><JournalIssue CitedMedium="Internet"><Volume>15</Volume><PubDate><Year>2025</Year></PubDate></JournalIssue><Title>Frontiers in cellular and infection microbiology</Title><ISOAbbreviation>Front Cell Infect Microbiol</ISOAbbreviation></Journal><ArticleTitle><i>Porphyromonas gingivalis</i>-induced periodontitis promotes neuroinflammation and neuronal loss associated with dysfunction of the brain barrier.</ArticleTitle><Pagination><StartPage>1559182</StartPage><MedlinePgn>1559182</MedlinePgn></Pagination><ELocationID EIdType="doi" ValidYN="Y">10.3389/fcimb.2025.1559182</ELocationID><Abstract><AbstractText Label="BACKGROUND" NlmCategory="UNASSIGNED">In our previous study, <i>Porphyromonas gingivalis</i> (<i>P. gingivalis</i>)-induced periodontitis caused cognitive impairment which was associated with abnormal amyloid β (Aβ) metabolite in the brain. The brain barrier is critical in maintaining homeostasis, controlling influx and efflux transport and regulating waste clearance. However, the specific role of the brain barrier in linking periodontitis to cognitive function remains unclear.</AbstractText><AbstractText Label="METHODS" NlmCategory="UNASSIGNED">A murine model of periodontitis-induced cognitive impairment was constructed via oral topical application of <i>P. gingivalis.</i> Neuroinflammation was observed by detecting the expression of proinflammatory cytokines and glia activation. Western blot (WB), immunohistochemistry (IHC) and immunofluorescence (IF) were used to detect the expression of tau-related molecules and neuronal loss. WB, Evans blue staining and flow cytometry were used to evaluate the blood-brain barrier (BBB) function including the infiltration of <i>P. gingivalis</i> and immune cells, and BBB permeability. The changes of meningeal lymphatic drainage were observed using an in vivo animal imaging system and reverse transcription polymerase chain reaction (RT-PCR). The effect of <i>P. gingivalis</i> on lymphatic endothelial cells (LECs) was further verified using IF and RT-PCR.</AbstractText><AbstractText Label="RESULTS" NlmCategory="UNASSIGNED"><i>P. gingivalis</i>-induced periodontitis exacerbated cognitive impairment by the upregulation of proinflammatory cytokine and glia activation. In the brain of periodontitis mice, p-Akt and p-GSK3β levels were reduced, leading to tau hyperphosphorylation and neuronal loss including cell bodies and neurites. <i>P. gingivalis</i>-induced periodontitis enhanced BBB permeability, promoted P. gingivalis and immune cell infiltration, and downregulated the expression of Occludin and ZO-1. In addition, the meningeal lymphatic drainage was impaired and the mRNA levels of lymphangiogenesis-related factor LYVE1 were decreased in the dura matter of periodontitis mice. After <i>P. gingivalis</i> infection, the inflammatory response was increased, and LYVE1 and ZO1 expression was decreased in LECs.</AbstractText><AbstractText Label="CONCLUSIONS" NlmCategory="UNASSIGNED">Periodontitis aggravated neuroinflammation and neuronal loss which was associated with tau hyperphosphorylation. The impaired meningeal lymphatic vessels (MLV) and disrupted BBB affected the brain barrier function, further inhibiting the clearance of pathogenic substances and enhancing immune cell infiltration in periodontitis mice. These results indicated that brain barrier dysfunction may be the link between periodontitis and cognitive impairment.</AbstractText><CopyrightInformation>Copyright © 2025 Jiang, Xu, Zhao, Shen, Qiu, He, Song and Zhou.</CopyrightInformation></Abstract><AuthorList CompleteYN="Y"><Author ValidYN="Y" EqualContrib="Y"><LastName>Jiang</LastName><ForeName>Yiting</ForeName><Initials>Y</Initials><AffiliationInfo><Affiliation>Department ...

# %%
text_content, s3_status = processor.get_s3_article_text('PMC12182182')
print(s3_status)
print(text_content[0:200])
# Out:
# Found
#
# ==== Front
# BMJ Open
# BMJ Open
# bmjopen
# bmjopen
# BMJ Open
# 2044-6055
# BMJ Publishing Group BMA House, Tavistock Square, London, WC1H 9JR
#
# 40533209
# 10.1136/bmjopen-2024-094965
# bmjopen-2024-094965
# Protocol
# G

# %%
article_type, type_confidence = processor.predict_article_type(articles[0])
# Out:
# Analyze the following article information to determine if it is a Review or Original Research. Provide a brief one-sentence rationale for your choice, followed by the classification. Use this format exactly:
# Rationale: [Your one-sentence reasoning]
# Classification: [Review or Original Research or Unknown]
#
# Information:
# Title: Subgingival microbiota and genetic factors (A-2570G, A896G, and C1196T TLR4 polymorphisms) as periodontal disease determinants.
# Abstract: Subgingival microbiota play an important role in maintaining oral health. Subgingival dysbiosis leads to the aggregation of highly pathogenic bacteria, and the host's genetics modulates the innate immune response. The interaction between these two factors plays an important role in the aggravation of periodontitis. Therefore, evaluating the association between the TLR-4 polymorphisms and subgingival microbiota in patients with periodontitis is necessary.
# We included 58 cases with periodontitis and 53 controls without periodontitis in this study. A896G, A-2570G, and C1196T polymorphisms of the
# The agonistic or antagonistic biological effect of each bacterial species depends on the genotype present in each individual and the destruction processes of dental support tissues.
# Rationale: The abstract describes a study with a specific methodology, including the inclusion of case and control groups and analysis of specific genetic polymorphisms, indicating original research.
# Classification: Original Research

# %%
print(article_type, type_confidence)
# Out:
# Original Research Medium

# %%
clean_abstract = processor.get_clean_abstract_from_xml(articles[6].xml)
print(clean_abstract)
# Out:
# INTRODUCTION: Concurrent with infants' progression in dietary complexity and gut microbiome diversity, infants gradually change their defecation patterns during the first year of life. However, the links between bowel habits, the gut microbiota and early life nutrition remain unclear. The primary outcome is to characterise the gut microbiome development from birth to 1 year of age. Second, to investigate how bowel habits and nutrition in early life relate to the gut microbiome and metabolome during this period of life, and to explore how the development of the gut microbiome associates with host development.
#
# METHODS AND ANALYSIS: The MOTILITY Mother-Child Cohort (MOTILITY) is a Danish prospective longitudinal cohort study enrolling up to 125 mother-infant dyads. Assessments occur at 36 weeks gestation (visit 1), birth (screening of infant) and 3, 6, 9 and 12 months (±2 weeks) post partum (visits 2-5). At visit 1, maternal anthropometrics, self-collected faecal and urine samples, and questionnaires on bowel habits and lifestyle are obtained. Between visits, infant faecal (biweekly), urine (monthly) and maternal breast milk (monthly until 6 months of age) samples are collected at home, and bowel habits and dietary intake are assessed biweekly by self-reported questionnaires. At visits 2-5, infant blood and saliva samples are collected, and anthropometric measurements are obtained. In addition, dietary intake is recorded thrice throughout the study period for mother and infant, respectively, and infant whole-gut transit time is estimated by sweet corn tests at 9 and 12 months of age. Birth, growth, motor development, sleep patterns, tooth development, overall health and well-being are assessed using questionnaires. Univariate and multivariate statistics will be applied to identify associations between the gut microbiome, early life nutrition and host physiology including bowel habits during the first year of life.
#
# ETHICS AND DISSEMINATION: The MOTILITY study has been approved by the Research Ethics Committee for the Capital Region of Denmark (reference number: H-21063016). Selected results will be made available to the participants in the form of a summary document. Results will be published in peer-review journals and by means of national and international conferences.
#
# TRIAL REGISTRATION NUMBER: NCT05491161.

# %%
seq_type, seq_quote = processor.predict_sequencing_type_advanced(clean_abstract, articles[6].keywords, text_content)
# Out:
# Tier 1: Analyzing abstract and keywords...
# Tier 2: Abstract/keywords inconclusive. Analyzing 'Methods' section of full text...

# %%
print(seq_type, seq_quote)
# Out:
# [16S, Shotgun] "The primary outcome will be a characterisation of changes in faecal microbial diversity and microbial community structures from longitudinal infant faecal samples collected biweekly from birth to 12 months of age, which will be analysed by 16S rRNA gene amplicon sequencing and shotgun metagenomic sequencing."

# %%
print(text_content)
# Out:
# ==== Front
# BMJ Open
# BMJ Open
# bmjopen
# bmjopen
# BMJ Open
# 2044-6055
# BMJ Publishing Group BMA House, Tavistock Square, London, WC1H 9JR
#
# 40533209
# 10.1136/bmjopen-2024-094965
# bmjopen-2024-094965
# Protocol
# Gastroenterology and Hepatology
# 1695
# 1506
# The MOTILITY Mother-Child Cohort: a Danish prospective longitudinal cohort study of the infant gut microbiome, nutrition and bowel habits – a study protocol
# https://orcid.org/0000-0002-4345-5182
# Stolberg-Mathieu Gladys 1
# https://orcid.org/0000-0001-7273-5733
# Mikkelsen Lasse Sommer 1
# Gottlieb Adam Duun 1
# Mølgaard Christian 1
# https://orcid.org/0000-0002-2504-8313
# Roager Henrik M. 1
# 1 Department of Nutrition, Exercise and Sports, University of Copenhagen, Frederiksberg, Denmark
# Supplemental material This content has been supplied by the author(s). It has not been vetted by BMJ Publishing Group Limited (BMJ) and may not have been peer-reviewed. Any opinions or recommendations discussed are solely those of the author(s) and are not endorsed by BMJ. BMJ disclaims all liability and responsibility arising from any reliance placed on the content. Where the content includes any translated material, BMJ does not warrant the accuracy and reliability of the translations (including but not limited to local regulations, clinical guidelines, terminology, drug names and drug dosages), and is not responsible for any error and/or omissions arising from translation and adaptation or otherwise.
#
# None declared.
#
# Dr Henrik M. Roager; hero@nexs.ku.dk
# 2025
# 18 6 2025
# 15 6 e09496511 10 2024
# 04 6 2025
# Copyright © Author(s) (or their employer(s)) 2025. Re-use permitted under CC BY-NC. No commercial re-use. See rights and permissions. Published by BMJ Group.
# 2025
# https://creativecommons.org/licenses/by-nc/4.0/ This is an open access article distributed in accordance with the Creative Commons Attribution Non Commercial (CC BY-NC 4.0) license, which permits others to distribute, remix, adapt, build upon this work non-commercially, and license their derivative works on different terms, provided the original work is properly cited, appropriate credit is given, any changes made indicated, and the use is non-commercial. See: http://creativecommons.org/licenses/by-nc/4.0/.
#
# Abstract
#
# Introduction
#
# Concurrent with infants’ progression in dietary complexity and gut microbiome diversity, infants gradually change their defecation patterns during the first year of life. However, the links between bowel habits, the gut microbiota and early life nutrition remain unclear. The primary outcome is to characterise the gut microbiome development from birth to 1 year of age. Second, to investigate how bowel habits and nutrition in early life relate to the gut microbiome and metabolome during this period of life, and to explore how the development of the gut microbiome associates with host development.
#
# Methods and analysis
#
# The MOTILITY Mother-Child Cohort (MOTILITY) is a Danish prospective longitudinal cohort study enrolling up to 125 mother–infant dyads. Assessments occur at 36 weeks gestation (visit 1), birth (screening of infant) and 3, 6, 9 and 12 months (±2 weeks) post partum (visits 2–5). At visit 1, maternal anthropometrics, self-collected faecal and urine samples, and questionnaires on bowel habits and lifestyle are obtained. Between visits, infant faecal (biweekly), urine (monthly) and maternal breast milk (monthly until 6 months of age) samples are collected at home, and bowel habits and dietary intake are assessed biweekly by self-reported questionnaires. At visits 2–5, infant blood and saliva samples are collected, and anthropometric measurements are obtained. In addition, dietary intake is recorded thrice throughout the study period for mother and infant, respectively, and infant whole-gut transit time is estimated by sweet corn tests at 9 and 12 months of age. Birth, growth, motor development, sleep patterns, tooth development, overall health and well-being are assessed using questionnaires. Univariate and multivariate statistics will be applied to identify associations between the gut microbiome, early life nutrition and host physiology including bowel habits during the first year of life.
#
# Ethics and dissemination
#
# The MOTILITY study has been approved by the Research Ethics Committee for the Capital Region of Denmark (reference number: H-21063016). Selected results will be made available to the participants in the form of a summary document. Results will be published in peer-review journals and by means of national and international conferences.
#
# Trial registration number
#
# NCT05491161.
#
# Microbiota
# Paediatric gastroenterology
# NUTRITION & DIETETICS
# http://dx.doi.org/10.13039/501100004836 Danmarks Frie Forskningsfond 0171-00006B 10.46540/3105-00178B The Independent Research Fund Denmark has no direct role in the design of this study nor the data collection, analysis or interpretation of the data or manuscript writing.
# ==== Body
# pmcSTRENGTHS AND LIMITATIONS OF THIS STUDY
#
# The use of omics technologies will allow the study of incremental changes in the gut microbiome and metabolome in relation to dietary transitions during the first year of life.
#
# Extensive metadata (eg, socioeconomic status, delivery mode, sleeping patterns) is collected and will enhance predictive power.
#
# Blood sampling at 3, 6, 9 and 12 months of age will allow the assessment of changes in blood immune cells, cytokines, appetite hormones and metabolome during infancy.
#
# This study does not follow the development of the infant gut microbiome until it has reached an adult-like composition.
#
# Due to the explorative nature of this study, external validation using data from other infant cohorts and/or dedicated mechanistic in vitro and in vivo follow-up experiments is needed.
#
# Introduction
#
# Gut microbiome establishment and development during infancy
#
# Microbes start colonising the infant’s oral cavity and gastrointestinal tract at birth, with subsequent gradual development and establishment of oral and gut microbiomes during infancy.17 These microorganisms play an essential role in human health by supporting several physiological processes such as digestion, metabolism and the maturation of the nervous and immune systems.1 5 8 Various perinatal and postnatal factors influence the establishment and development of the infant gut microbiome,9 including maternal health,10 mode of delivery,1113 gestational age,14 15 intrapartum antibiotic prophylaxis,1618 postnatal application of antibiotics,1719 breastfeeding,20 as well as exposure to parents,21 siblings and pets,2224 along with hospital25 and domestic environments.26 While there is a growing appreciation that nutrition in early life strongly affects the development of the infant gut microbiome,27 28 which is linked to metabolic, hormonal, mental and immunological development,1 5 29 the underlying interplay between dietary patterns, gut microbiome development and host physiology remains elusive.
#
# Early life nutrition and the infant gut microbiome
#
# Diet is the most fundamental and decisive factor driving the composition and development of the gut microbiome during the first year of life.20 28 30 31 The initial infant diet is liquid-based in the form of breast milk and/or formula milk, each affecting the gut microbiome differently. Breast milk, rich in human milk oligosaccharides (HMOs), promotes the growth of Bifidobacterium species.203234 These have been suggested to support metabolic functions accommodating changes in amino acid levels in breast milk27 and to influence the oral microbiome.7 35 Formula milk has been shown to induce a difference in gut microbial diversity and composition compared with the bifidobacteria-dominated gut microbiome in breastfed infants.20 31 36 37 The different feeding regimens have also been linked to differences in gut bacteria-derived metabolites,38 including short-chained fatty acids (SCFAs).39 40 As infants begin complementary feeding (CF) around 4–6 months of age, their gut microbiome undergoes significant changes during the transition from milk to solid foods. While CF is essential for health and development, its impact on gut microbiome development has been less studied.41 42 Research shows that CF, and in particular the cessation of breastfeeding, alters gut microbial composition and metabolites,404345 but previous studies often captured dietary patterns at only one or a few time points,28 limiting insight into the gradual changes.
#
# The infant gut microbiome and links to host physiology
#
# Defecation patterns in early life
#
# Defecation patterns (frequency and consistency) vary significantly between and within infants in the first months of life, especially according to feeding mode (breastfed vs formula fed).46 47 Additionally, gut motility-related conditions, including constipation, diarrhoea and infantile colic, are prevalent in infants.48 49 Diet can affect gut motility in a microbiota-dependent and a microbiota-independent way,50 suggesting a complex interplay between diet, gut microbiome and gut motility. Indeed, gut transit time in adults has been found to associate with the gut microbiome diversity and functionality.51 Furthermore, recent studies have shown that microbiota-derived products, such as SCFAs and biogenic amines,52 can affect gut motility,5356 primarily through specific receptors found in intestinal cells.57 Although it is well established that defecation patterns change during infancy,46 47 the links to diet and gut microbiome remain elusive in the context of early life.
#
# Development of the immune system
#
# Gut microbes and microbial-derived metabolites affect the development of the immune system in early life.58 For example, a study on Swedish infants showed that infants lacking Bifidobacterium species had improper immune development.45 Additionally, aromatic lactic acids produced by Bifidobacterium species are suggested to affect immune function in early life.5962 Impaired immune development in infancy can lead to a higher risk of immunological diseases in childhood,45 63 influenced by microbial composition, diet-derived metabolites and microbial metabolites.64 65 Thus, investigating the associations between early life nutrition, gut microbiome development and immune system markers is essential. Biomarkers of the immune system, such as cytokines, immune cells and antibodies, in faeces and blood can provide insights into immune development and be linked to the gut microbiome development.66
#
# Physical and cognitive development during infancy
#
# The infant gut microbiome and metabolome have been correlated with specific infant growth indices like weight and weight gain.67 Conditions such as intrapartum antibiotic exposure, preterm birth,68 and rapid infant growth69 have been shown to associate with the gut microbiome and affect various measures of growth like weight, body mass index (BMI) and anthropometric Z-scores. A mechanistic study showed that antibiotic exposure can impair growth by transferring infant gut microbiomes exposed to antibiotics to gnotobiotic mice.70 These effects on growth may extend into childhood and adolescence.71 Neurological development has similarly been linked to gut microbiome development,72 affecting motor skills,73 74 memory,75 cognition29 76 and language.29 77 Behavioural measures like crying time78 79 and sleep patterns80 have likewise been linked to the infant gut microbiome. Thus, the infant gut microbiome appears to be crucial for both physical and cognitive development.
#
# Objectives
#
# The aim of this study is to investigate how bowel habits and nutrition in early life relate to the gut microbiome and metabolome from birth to 12 months of age, and to explore how the development of the gut microbiome associates with host development.
#
# Methods and analysis
#
# Study design
#
# The MOTILITY Mother-Child Cohort (MOTILITY) is a prospective longitudinal observational cohort study following mother–infant dyads from gestational week 36 to 1 year post partum.
#
# Recruitment and setting
#
# Pregnant women expecting a non-complicated pregnancy who meet the eligibility criteria are recruited in the Greater Copenhagen area, Denmark, through social media, relevant websites, podcasts, public domains (libraries and educational institutions) and relevant organisations (midwife associations and birth preparation courses). At in-person information meetings, the study is thoroughly explained, and participants are provided with verbal, written and pictorial instructions for samples and data collection. To minimise loss to follow-up, efforts are made to establish a positive researcher–participant relationship and to ensure the provision of clear information. Thereafter, written informed consents are collected from interested and eligible pregnant women. Written informed consents for the infants are collected before they are born at visit 1, at week 36 of gestation, with signatures from all custody holders of the infant.
#
# Eligibility criteria
#
# Mothers enter the study after screening for compliance with the eligibility criteria (see box 1). To ensure that pregnant women have sufficient time to receive both written and oral information about the study and to complete necessary tasks before visit 1 at week 36 of gestation, we set an exclusion criterion that the pregnancy must not be beyond week 34 at the time of recruitment. Furthermore, infants born during week 36, after visit 1, will be enrolled although being very late preterm. As written consent forms for the infants are collected prenatally, a screening of the infants for compliance with the eligibility criteria (see box 1) takes place shortly post partum.
#
# Box 1 Eligibility criteria
#
# Inclusion criteria
#
# Mother
#
# Between the age of 18 and 40 years at inclusion.
#
# Speaking and understanding Danish.
#
# Willing to store biological samples in their private freezer.
#
# Infant
#
# Born at 36 weeks of gestation or later.
#
# Exclusion criteria
#
# Mother
#
# At gestational week 34 or more at time of recruitment.
#
# Diagnosed with any severe or chronic diseases.
#
# Diagnosed with gestational diabetes and/or pre-eclampsia during current pregnancy.
#
# Expecting triplets or higher order of multiple pregnancy.
#
# Concurrent participation in another study.
#
# Not capable of following the examinations according to the investigator’s instructions.
#
# Infant
#
# Diagnosed with any severe or chronic diseases.
#
# Study setup, data collection and analyses
#
# The study flow including visits, activities and collection of biological samples and data is illustrated in figure 1. After the prescreening, included participants are given a folder containing instructions and questionnaires together with material for collection of biological samples. Assessment occurs 1 month prior to the expected due date, at 36 weeks gestation (visit 1), at birth (screening of infant) and at 3, 6, 9 and 12 months (±2 weeks) post partum (visits 2–5). Participants’ schedules will be accommodated by offering flexible visit times (±2 weeks) for each visit post partum. Additionally, flexibility will be provided in completing specific components of the study to keep participants engaged and reduce dropout. For instance, participants expressing discomfort with blood draws will have their concerns addressed and be encouraged to complete the other aspects of the study. All study visits are conducted at the Department of Nutrition, Exercise and Sports at the University of Copenhagen, Denmark. During the study, participants perform self-collection of faecal, urine and breast milk samples, perform 3-day dietary records at three time points, complete two sweet corn tests, record dental development and fill out questionnaires about dietary intake, bowel habits, lifestyle, birth, infant growth and infant health, well-being and development. At visits, blood and saliva samples are collected, anthropometric measurements are performed and motor development is assessed. An overview of samples and data to be collected during this study is shown in online supplemental table S1. Automated email and text reminders will be sent for sample collection, and recordings of bowel habits and dietary intake, as well as before each scheduled visit.
#
# Figure 1 Study flow of the MOTILITY Mother-Child Cohort (MOTILITY), a Danish prospective longitudinal cohort study following mother–infant dyads from 1 month before birth throughout the first year of life. Assessment occurs at gestational week 36 (visit 1), birth (screening of infant), and 3, 6, 9 and 12 months (±2 weeks) post partum (visits 2–5). At visit 1, self-collected maternal faecal and urine samples are obtained together with a bowel habit questionnaire, a lifestyle questionnaire, anthropometric measurements and an infant consent form. Dietary records are completed three times throughout the study period for 3 days using the validated, online programme myfood24 for mothers (around visits 1, 2 and 4) and infants (around visits 3, 4 and 5), respectively. Between visits 1–5, participants collect infant faecal (biweekly from 2 to 3 days after birth), infant urine (monthly from 2 to 3 days after birth) and breast milk (monthly from 1 to 6 months of age and if possible) samples, perform sweet corn tests (twice between visit 4 and 5) and fill out questionnaires about infant dietary intake (biweekly), infant bowel habits (biweekly), birth, infant growth (noted until visit 2), infant dental development and infant health, well-being and development (assessed at 3, 6, 9 and 12 months of age). At visits 2–5, infant blood and saliva samples are collected, motor development milestones are assessed, and anthropometric measurements are performed. Created in BioRender. Stolberg-Mathieu, G. (2024) BioRender.com/p01a623.
#
# Home sampling, storage and transportation of biological samples
#
# Faecal, urine and breast milk samples are collected at home with provided material for collection and immediately stored at −20°C in the freezer of the participant. The samples are transported in a cooler bag with freezer packs to the study site at each visit. Immediately after reception, the frozen samples are stored at −70°C. At study visits 1–4, participants are provided with new collection material for upcoming study visits.
#
# Faecal samples and defecation patterns
#
# Faecal samples
#
# One maternal faecal sample will be collected 1–2 days prior to study visit 1 by evacuation into a white plastic container with lid (Grathwol, Karlslunde, Denmark).
#
# Infant faecal samples are collected biweekly from 2 to 3 days after birth until 12 months of age using a plastic tube with spatula (Sarstedt, Nümbrecht, Germany) to transfer faeces from the diaper (5 mL per sample). A biodegradable sheet is placed in the diaper prior to collection during the breastfeeding and/or formula feeding period, to limit absorption of liquid faecal material by the diaper. After reception, the faecal samples are homogenised with Milli-Q water (1:1), pH is measured, and the samples are divided into aliquots and stored at −70°C until further analysis.
#
# Bowel habits
#
# A questionnaire on maternal bowel habits including the Bristol Stool Scale81 is completed in connection with the collection of the maternal faecal sample prior to visit 1.
#
# Infant bowel habit questionnaires are completed biweekly whenever a stool sample is collected, starting from 2 to 3 days after birth or as soon as possible hereafter (online supplemental appendix 1). The questionnaire collects data on stool consistency using a modified version of the Diapered Infant Stool Scale,82 which includes an additional category called type 0 (separated hard balls/lumps) specifically added for this study. Furthermore, stool colour is assessed using the ‘Amsterdam’ Infant Stool Scale,83 and stool frequency and daily crying time for the past week is obtained. If applicable, any use of common analgesics, laxatives, antibiotics and other medications, as well as any infant gastrointestinal disturbances experienced in the past week is noted.
#
# Whole-gut transit time
#
# Infants will undergo a modified sweet corn test84 twice between visits 4 and 5, at the age of around 9 and 12 months, respectively. At home, when parents deem that the infant is comfortable with solid foods, the infant will consume approximately 10 g of sweet corn. Parents will record the date and time of consumption. Subsequently, parents will record the date and time of the sweet corn’s appearance in faeces, which will enable the estimation of the infant’s whole-gut transit time.
#
# Additional biological samples
#
# Urine samples
#
# One maternal fasting morning urine spot sample will be collected at home 1–2 days prior to visit 1. The spot urine sample will be obtained by using the Vacuette Urine Collection System (Greiner Bio-One, Kremsmünster, Austria), consisting of a urine beaker and an integrated transfer device permitting clean transfer and collection of urine from the beaker. From 2 to 3 days after birth until 12 months of age, infant urine samples will be collected monthly at home. Cotton balls will be used for absorption of urine and placed in the diaper on the day for sample collection. A biodegradable sheet will also be placed in the diaper to allow for increased absorption of urine by the cotton balls. At the study site, the wet cotton balls are squeezed with a syringe to extract the urine. Both maternal and infant urine samples are aliquoted and stored at −70°C.
#
# Breast milk samples
#
# Breast milk samples will be obtained monthly from lactating mothers between visits 1 and 3. Collection of samples will begin 1 month after birth and last until infants are up to 6 months of age. Mothers will be asked to manually express the breast milk (2–5 mL per sample) by hand into a pathology container (DACOS A/S, Denmark) during breastfeeding. The breast milk is collected after the first few drops. At the study site, the samples are aliquoted and stored at −70°C.
#
# Blood samples
#
# Blood samples will be collected from the infants at visits 2–5, whenever possible. Blood will be drawn from the elbow by venipuncture (3×2 mL per sample), using a BD Vacutainer Blood Collection Set (Becton, Dickinson and Company, New Jersey, USA). Before blood is drawn, local anaesthetics (EMLA band aid or crème) will be applied to the point of venipuncture. Sucrose analgesia will be used and given to the infants 30–60 s before and during blood collection using a syringe and pacifier (if relevant). Up to 6 mL of blood will be collected and distributed into three tubes: (1) heparin, 2 mL tube (first priority) for peripheral blood mononuclear cells, (2) serum, 2 mL tube (second priority) for metabolomics and (3) EDTA, 2 mL tube (third priority) for hormones. Immune cells are extracted by adding blood from the heparin sample together with sterile saline to a Lymphoprep solution. Hereafter, the mononuclear cells are separated by centrifugation, then carefully collected, diluted with sterile saline and centrifuged again to form a pellet. The cells are then resuspended in a Foetal Bovine Serum and dimethyl sulfoxide mixture, aliquoted and frozen at −70°C. For long-term storage, the cryotubes containing the immune cells are moved to a liquid nitrogen tank and subsequently stored in a −140°C freezer.
#
# Saliva samples
#
# At visits 2–5, infant saliva samples (1–2 mL) will be obtained with SalivaBio Children’s Swaps (Salimetrics, State College, Pennsylvania, USA), a synthetic swab specially designed for infants, minimising the risk of choking hazard. The samples are centrifuged, aliquoted and stored at −70°C.
#
# Anthropometric measurements
#
# At visit 1, maternal height and weight are measured. Before measuring, the participants will be asked to remove shoes, bulky clothing and heavy jewellery, as well as to empty their bladder. Height is measured three times using a Seca wall-mounted stadiometer (Seca Denmark, Hamburg, Germany), and the mean value will be used for analysis. Weight is measured once with a TANITA MC 780 MA digital weight (TANITA Danmark, Søborg, Denmark). Gestational weight gain, as well as habitual and gestational BMI, will be calculated based on measures from visit 1 and on habitual weight obtained through a questionnaire. At visits 2–5, infant length is measured three times using a Seca 416 infantometer and weight is measured once with a TANITA BD 815 MA digital infant weight (TANITA Danmark, Søborg, Denmark). Infants will be naked when measuring length and weight. Infant head circumference is measured three times with a Seca 212 measuring tape (Seca Denmark, Hamburg, Germany). Triceps and subscapular skinfold are measured three times respectively using a Harpenden skinfold calliper (CMS Weighing Equipment, London, UK). Calculated mean values will be used for analysis. For each time point (3, 6, 9 and 12 months of age), BMI-for-age Z-scores will be determined using the WHO Child Growth Standards.
#
# Dietary assessment
#
# Dietary records
#
# 3-day dietary records are collected throughout the study at different time points using the validated self-administered online 24-hour dietary registration tool myfood24. Maternal dietary records are collected prior to visits 1, 2 and 4, and infant dietary records prior to visits 3, 4 and 5. In this study, the Danish version of myfood24 is used, which is codeveloped by the Danish Cancer Society and includes several food databases specific for Denmark, together with the Infant database, created by the University of Copenhagen. For study participants, myfood24 provides guiding images and descriptions of portion sizes, reminders of often forgotten foods and the possibility of creating recipes.
#
# Food frequency questionnaire
#
# A Food Frequency Questionnaire (FFQ), including breast milk, formula milk, 31 commonly consumed food items sub grouped into seven food categories (porridge, bread, pasta/rice, vegetables, animal products (including meat and dairy products) and other), and dietary supplements, will be used to collect information about infant dietary patterns (composition, complexity, quality and timing) biweekly from 2 to 3 days after birth to 12 months of age, capturing both full and partial breastfeeding/formula feeding and the dietary transitions from milk consumption through weaning to solid food consumption (online supplemental appendix 2).
#
# Lifestyle, birth, growth and development
#
# Lifestyle questionnaire
#
# Prior to visit 1, participants complete a digital questionnaire about sociodemographic factors (age, maternal ethnicity, living conditions and household, parental educations, household income and parental employments), maternal lifestyle (alcohol consumption, smoking, exercise habits, dietary preferences) and maternal health (pregnancy, prepregnancy body weight, medical history of asthma, eczema, allergies, lactose intolerance and coeliac disease, medication usage (including antibiotics) during pregnancy, consumption of dietary supplements).
#
# Birth information and infant growth
#
# Information about birth and infant growth is obtained through self-reported questionnaires that are submitted to the project staff at visit 2. Birth information includes date of birth, birth weight and length, head circumference, Apgar score (5 min), mode of delivery (vaginal birth, assisted vaginal birth, caesarean section), site of birth (hospital, home, other location) and medications administered during birth (antibiotics or other medications). Information on infant growth during the first 3 months after birth includes measurements on weight, length and head circumference made by community health nurses during home-based visits. Visits by community health nurses are a healthcare service provided by all Danish municipalities.
#
# Infant health, well-being and development questionnaire
#
# Questionnaires concerning the infant will be completed prior to visits 2–5. These include questions on hospitalisation and illness, vaccination, well-being, sleeping patterns (based on the Brief Infant Sleep Questionnaire85), pacifier usage and regurgitation. The questionnaire for visit 2 additionally enquires about information related to birth and gender of the child. Questions on infant mental health and development are based on the Copenhagen Infant Mental Health Screening86 and are enquired about prior to study visits 4 and 5. Additionally, questionnaires before visits 4 and 5 enquire about information about when the child began daycare.
#
# Infant motor development
#
# At visits 2–5, infant motor development is evaluated according to the WHO gross motor development milestones.87 In brief, a parent of the infant indicates at each study visit if and when (age in weeks and months) the infant has reached one of the six milestones: sitting without support, hands-and-knees crawling, standing with assistance, walking with assistance, standing alone and walking alone.
#
# Dental development
#
# Information about infant dental development will be collected through a physical questionnaire that includes an illustration of teeth in the upper and lower jaw. Throughout the study period, parents record the date of teeth eruptions indicated by the date the parents start brushing each tooth.
#
# Outcomes
#
# Primary outcome
#
# The primary outcome will be a characterisation of changes in faecal microbial diversity and microbial community structures from longitudinal infant faecal samples collected biweekly from birth to 12 months of age, which will be analysed by 16S rRNA gene amplicon sequencing and shotgun metagenomic sequencing.
#
# Secondary outcomes
#
# Infant faecal metabolome assessed by untargeted metabolomics from birth to 12 months of age.
#
# Changes in infant bowel habits as measured by stool frequency, consistency, and colour from birth to 12 months of age.
#
# Whole-gut transit time assessed by a sweet corn test at 9 and 12 months of age.
#
# Changes in infant dietary patterns recorded using FFQs from birth to 12 months of age.
#
# Assessment of dietary intake using 3-day dietary records at 6, 9 and 12 months of age.
#
# Changes in total faecal bacterial load as measured by quantitative PCR or flow cytometry from birth to 12 months of age.
#
# Changes in infant body composite consisting of weight, length, BMI, BMI z-scores and head circumference from birth to 3 months of age and at 6, 9 and 12 months of age.
#
# Changes in infant fat stores assessed by skin fold (triceps and subscapular) measurements at 3, 6, 9 and 12 months of age.
#
# Changes in infant urine metabolome as assessed by untargeted metabolomics.
#
# Other explorative outcomes
#
# Changes in infant faecal SCFA production as measured by targeted metabolomics from birth to 12 months of age.
#
# Changes in faecal pH from birth to 12 months of age.
#
# Changes in faecal oligosaccharide residues from birth to 12 months of age.
#
# Changes in faecal proteome (food-related and microbiota-related antigens) from birth to 12 months of age.
#
# Changes in faecal immune-related markers (cytokines, immunoglobulins and lipopolysaccharides) from birth to 12 months of age.
#
# Changes in immune cells and cytokines in blood at 3, 6, 9 and 12 months of age.
#
# Changes in infant blood metabolome at 3, 6, 9 and 12 months of age as assessed by untargeted metabolomics.
#
# Concentrations of appetite hormones in infant blood at 3, 6, 9 and 12 months of age.
#
# Changes in maternal breast milk metabolome from 1 to 6 months post partum as assessed by untargeted metabolomics.
#
# Changes in maternal breast milk HMOs from 1 to 6 months post partum measured by metabolomics.
#
# Infant gastrointestinal symptoms and related symptoms (fever, bloating, vomiting, diarrhoea, constipation, irritability (crying time)) from birth to 12 months of age.
#
# General health status of the infant in relation to the occurrence of any illness, healthcare visits for sickness and use of antibiotics and medication from birth to 12 months of age.
#
# Maternal dietary intake assessed by 3-day dietary records at gestational week 36, as well as at 3 and 9 months post partum.
#
# Changes in infant saliva microbiome and metabolome measured by DNA/RNA sequencing and untargeted metabolomics, respectively, at 3, 6, 9 and 12 months of age.
#
# Infant tooth development during the first year of life.
#
# Infant sleep patterns during the first year of life based on the Brief Infant Sleep Questionnaire.85
#
# Infant motor development during the first year of life assessed by the WHO motor development milestones.87
#
# Infant mental health assessed by the Copenhagen Mental Health Screening86 at 9 and 12 months of age.
#
# Furthermore, associations between the infant gut microbiome community (structure and function) and perinatal factors (environment, nutrition, pharmacological exposure) will be investigated. Moreover, associations with other maternal factors (lifestyle, anthropometry, pharmacological exposure) and birth mode (mode of delivery, perinatal pharmacological exposure, gestational age) will be explored.
#
# Sample size
#
# The association and interaction between nutrition, bowel habits and the infant gut microbiome and metabolome during the first year of life is still a widely unexplored topic in microbiome research, which is why few studies are available for sample size estimation. Yet, a previous study investigating the effect of dietary patterns on infant microbiome development included 114 mother–infant pairs and found significant associations between infant microbiome and dietary patterns at 9 and 18 months of age.28 Similarly, a more recent study based on microbiome profiles from 74 infants at 7 and 12 months of age, investigating the effect of traditional weaning practices compared with a modified version of baby-led weaning, found an association between dietary components and infant gut microbial composition.43 Thus, we estimated that 100 mother–infant pairs would sufficiently cover the microbial diversity variation in the CF period. With an expected dropout rate of 20%, we planned to include a total of 125 mother–infant dyads.
#
# Statistical analysis and data integration
#
# Statistical analyses will be performed using R software. Participant dropout over the 1-year study period is unavoidable, which is why statistical analyses will, to the largest extent possible, be conducted using all available data and imputations. When appropriate, sensitivity analyses (eg, comparing dropouts and completers) will be performed to evaluate the potential impact of missing data on the study findings. Descriptive statistics of mothers and infants will be presented as either means with SD if normally distributed, or as median and IQR if abnormally distributed, as well as counts and percentages. Additionally, data visualisation tools will be used to graphically depict the data. The data will be integrated by use of linear mixed models, repeated measures correlation and multivariate analyses considering the longitudinal study design. Adjustment for multiple testing will be applied. The gut microbiome profiles will be characterised within samples using measures of α-diversity, and between-samples differences using measures of β-diversity with and without adjustment for total bacterial load, similar to previous studies.60 88
#
# Patient and public involvement
#
# Patients and the public were not involved in the design or development of this study. Participating mother–infant dyads will receive diplomas with the overall study results as well as their own results.
#
# Ethics and dissemination
#
# Ethical approval and registration
#
# This study was approved by the Capital Region’s Committee on Health Research Ethics in the Capital Region of Denmark in accordance with the Helsinki declaration (H-21063016) and the Data Protection Agency. The study was prospectively registered with the National Institutes of Health (US) Clinical Trial Registry (ClinicalTrials.gov) under the registration number: NCT05491161.
#
# Data management, consent and confidentiality
#
# Written informed consent is obtained from all participants prior to enrolment in the study. The participants will be informed that participation in the study is voluntary and that they may withdraw consent and withdraw from the study at any time. To ensure the confidentiality of the participants in the study, all participating mother–infant dyads will be assigned a unique identification code in a pseudonymised format. Pseudonymised information will be used in metadata records, and no personal information will be made public at any point.
#
# Data on participants will be entered into secure, web-based electronic databases (REDCap and EasyTrial) protected by passwords, and with access restricted to relevant study staff only. Participant data will also be compiled in physical folders stored behind double locks.
#
# Dissemination of results
#
# The investigators are responsible for the study results and have the right to publish them. The findings will be published in peer-reviewed journals and presented at national and international conferences. To ensure accessibility beyond the scientific community, the results will also be shared with the public through press releases, popular articles, social media and public engagement events.
#
# Discussion
#
# The MOTILITY Mother-Infant cohort stands out due to its biweekly longitudinal stool sampling, along with frequent recordings of dietary patterns and bowel habits during the first year of life. The study will make a significant contribution to the scientific community by deeply examining the role of early life nutrition and bowel habits in shaping the infant gut microbiome, as well as exploring the connections between infant gut microbiome development and host physiology, including gut motility. By uncovering diet-microbiome-host associations in infants, we may identify new mechanisms by which nutrition, via microbiota-dependent and microbiota-independent pathways, influences intestinal motility and other physiological measures. Additionally, the cohort study will provide insights into how diet-microbiota interactions relate to metabolic, hormonal, mental and immunological development in early life, which could be crucial for lifelong health. The inclusion of extensive metadata, such as socioeconomic status, delivery mode and sleeping patterns, will enhance the study’s predictive power and enable more nuanced analyses. However, some limitations to the study should be mentioned. First, while self-collection of biological samples allows for higher sample frequency enabling the study of the incremental changes in the infant gut microbiome, the quality of samples might be compromised due to possible variations in sampling procedures and storage at home, despite thorough instructions provided to minimise these differences. Second, the study does not follow the development of the infant gut microbiome until it reaches maturity, which typically occurs between 2 and 3 years of age.6 Third, the explorative nature of the study should also be mentioned. While novel hypotheses are likely to be generated from the cohort study, external validation using data from other infant cohorts such as CIG,89 MILQ,90 SKOT91 and INFANTMET92 and/or dedicated mechanistic in vitro and in vivo experiments is needed. We recently applied such a framework using a similar infant cohort including 25 infants, which was followed from birth to 6 months of age. Despite the relatively low sample size, the longitudinal design enabled us to identify novel diet-microbe-metabolite associations, which we later validated using data from other cohorts and mechanistic experiments.60 93 This underlines the potential of combining a longitudinal infant cohort with mechanistic follow-up experiments to discover important and novel diet-dependent gut microbial metabolites, which may be pivotal mediators of host physiology in early life.
#
# Supplementary material
#
# 10.1136/bmjopen-2024-094965 online supplemental file 1
#
# 10.1136/bmjopen-2024-094965 online supplemental file 2
#
# 10.1136/bmjopen-2024-094965 online supplemental file 3
#
# Acknowledgements
#
# We would like to thank our colleague Le Lene Susanne Simon Stevner for her helpful guidance with regards to protocol writing, Good Clinical Practice and General Data Protection Regulation. We sincerely thank Jane Guldborg Jørgensen, bioanalyst at the Department of Nutrition, Exercise and Sports, for her contribution to the MOTILTIY project preparation.
#
# Review Process File
# 18 06 2025
#
# Funding: This study was supported by the Independent Research Fund Denmark (MOTILITY; 0171-00006B and AROMA; 3105-00178B).
#
# Prepublication history and additional supplemental material for this paper are available online. To view these files, please visit the journal online (https://doi.org/10.1136/bmjopen-2024-094965).
#
# Provenance and peer review: Not commissioned; externally peer reviewed.
#
# Patient consent for publication: Not applicable.
#
# Patient and public involvement: Patients and/or the public were not involved in the design, or conduct, or reporting, or dissemination plans of this research.
# ==== Refs
# References
#
# 1 Dominguez-Bello MG Godoy-Vitorino F Knight R et al Role of the microbiome in human development Gut 2019 68 1108 14 10.1136/gutjnl-2018-317503 30670574
# 2 Tannock GW Building Robust Assemblages of Bacteria in the Human Gut in Early Life Appl Environ Microbiol 2021 87 e01449-21 10.1128/AEM.01449-21 34469198
# 3 Ferretti P Pasolli E Tett A et al Mother-to-Infant Microbial Transmission from Different Body Sites Shapes the Developing Infant Gut Microbiome Cell Host Microbe 2018 24 133 45 10.1016/j.chom.2018.06.005 30001516
# 4 Toda K Hisata K Satoh T et al Neonatal oral fluid as a transmission route for bifidobacteria to the infant gut immediately after birth Sci Rep 2019 9 8692 8692 10.1038/s41598-019-45198-9 31213639
# 5 Tamburini S Shen N Wu HC et al The microbiome in early life: implications for health outcomes Nat Med 2016 22 713 22 10.1038/nm.4142 27387886
# 6 Stewart CJ Ajami NJ O’Brien JL et al Temporal development of the gut microbiome in early childhood from the TEDDY study Nature New Biol 2018 562 583 8 10.1038/s41586-018-0617-x
# 7 Blum J Silva M Byrne SJ et al Temporal development of the infant oral microbiome Crit Rev Microbiol 2022 48 730 42 10.1080/1040841X.2021.2025042 35015598
# 8 Dzidic M Abrahamsson TR Artacho A et al Oral microbiota maturation during the first 7 years of life in relation to allergy development Allergy 2018 73 2000 11 10.1111/all.13449 29602225
# 9 Milani C Duranti S Bottacini F et al The First Microbial Colonizers of the Human Gut: Composition, Activities, and Health Implications of the Infant Gut Microbiota Microbiol Mol Biol Rev 2017 81 e00036-17 10.1128/MMBR.00036-17
# 10 Grech A Collins CE Holmes A et al Maternal exposures and the infant gut microbiome: a systematic review with meta-analysis Gut Microbes 2021 13 1 30 10.1080/19490976.2021.1897210
# 11 Dominguez-Bello MG Costello EK Contreras M et al Delivery mode shapes the acquisition and structure of the initial microbiota across multiple body habitats in newborns Proc Natl Acad Sci U S A 2010 107 11971 5 10.1073/PNAS.1002601107/SUPPL_FILE/PNAS.201002601SI.PDF 20566857
# 12 Shao Y Forster SC Tsaliki E et al Stunted microbiota and opportunistic pathogen colonization in caesarean-section birth Nature New Biol 2019 574 117 21 10.1038/s41586-019-1560-1
# 13 Munyaka PM Khafipour E Ghia JE External influence of early childhood establishment of gut microbiota and subsequent health implications Front Pediatr 2014 2 10.3389/FPED.2014.00109/BIBTEX
# 14 Fouhy F Watkins C Hill CJ et al Perinatal factors affect the gut microbiota up to four years after birth Nat Commun 2019 10 1517 10.1038/s41467-019-09252-4 30944304
# 15 Cuna A Morowitz MJ Ahmed I et al Dynamics of the preterm gut microbiome in health and disease Am J Physiol Gastrointest Liver Physiol 2021 320 G411 9 10.1152/ajpgi.00399.2020 33439103
# 16 Garcia VR Impact of Intrapartum Antibiotic Prophylaxis for Group B Streptococcus on the Term Infant Gut Microbiome: A State of the Science Review J Midwife Womens Health 2021 66 351 9 10.1111/jmwh.13245
# 17 Ainonen S Tejesvi MV Mahmud MR et al Antibiotics at birth and later antibiotic courses: effects on gut microbiota Pediatr Res 2022 91 154 62 10.1038/s41390-021-01494-7 33824448
# 18 Tapiainen T Koivusaari P Brinkac L et al Impact of intrapartum and postnatal antibiotics on the gut microbiome and emergence of antimicrobial resistance in infants Sci Rep 2019 9 10635 10.1038/s41598-019-46964-5 31337807
# 19 Reyman M van Houten MA Watson RL et al Effects of early-life antibiotics on the developing infant gut microbiome and resistome: a randomized trial Nat Commun 2022 13 893 10.1038/s41467-022-28525-z 35173154
# 20 Laursen MF Gut Microbiota Development: Influence of Diet from Infancy to Toddlerhood Ann Nutr Metab 2021 77 1 14 10.1159/000517912
# 21 Dubois L Valles-Colomer M Ponsero A et al Paternal and induced gut microbiota seeding complement mother-to-infant transmission Cell Host Microbe 2024 32 1011 24 10.1016/j.chom.2024.05.004 38870892
# 22 Hasegawa K Linnemann RW Mansbach JM et al Household siblings and nasal and fecal microbiota in infants Pediatr Int 2017 59 473 81 10.1111/ped.13168 27638139
# 23 Lane AA McGuire MK McGuire MA et al Household composition and the infant fecal microbiome: The INSPIRE study Am J Phys Anthropol 2019 169 526 39 10.1002/ajpa.23843 31012086
# 24 Laursen MF Zachariassen G Bahl MI et al Having older siblings is associated with gut microbiota development during early childhood BMC Microbiol 2015 15 1 9 10.1186/S12866-015-0477-6/FIGURES/4 25591663
# 25 Sarkar A Yoo JY Valeria Ozorio Dutra S et al The Association between Early-Life Gut Microbiota and Long-Term Health and Diseases J Clin Med 2021 10 1 24 10.3390/jcm10030459
# 26 von Mutius E The microbial environment and its influence on asthma prevention in early life J Allergy Clin Immunol 2016 137 680 9 10.1016/j.jaci.2015.12.1301 26806048
# 27 Baumann-Dudenhoeffer AM D’Souza AW Tarr PI et al Infant diet and maternal gestational weight gain predict early metabolic maturation of gut microbiomes Nat Med 2018 24 1822 9 10.1038/s41591-018-0216-2 30374198
# 28 Laursen MF Andersen LBB Michaelsen KF et al Infant Gut Microbiota Development Is Driven by Transition to Family Foods Independent of Maternal Obesity mSphere 2016 1 e00069-15 10.1128/mSphere.00069-15
# 29 Tamana SK Tun HM Konya T et al Bacteroides-dominant gut microbiome of late infancy is associated with enhanced neurodevelopment Gut Microbes 2021 13 1 17 10.1080/19490976.2021.1930875
# 30 Jain N Walker WA Diet and host-microbial crosstalk in postnatal intestinal immune homeostasis Nat Rev Gastroenterol Hepatol 2015 12 14 25 10.1038/nrgastro.2014.153 25201040
# 31 Iozzo P Sanguinetti E Early Dietary Patterns and Microbiota Development: Still a Way to Go from Descriptive Interactions to Health-Relevant Solutions Front Nutr 2018 5 5 10.3389/fnut.2018.00005 29457002
# 32 Sakanaka M Hansen ME Gotoh A et al Evolutionary adaptation in fucosyllactose uptake systems supports bifidobacteria-infant symbiosis Sci Adv 2019 5 eaaw7696 10.1126/sciadv.aaw7696 31489370
# 33 Sakanaka M Gotoh A Yoshida K et al Varied Pathways of Infant Gut-Associated Bifidobacterium to Assimilate Human Milk Oligosaccharides: Prevalence of the Gene Set and Its Correlation with Bifidobacteria-Rich Microbiota Formation Nutrients 2020 12 71 10.3390/nu12010071
# 34 Kujawska M La Rosa SL Roger LC et al Succession of Bifidobacterium longum Strains in Response to a Changing Early Life Nutritional Environment Reveals Dietary Substrate Adaptations iScience 2020 23 101368 10.1016/j.isci.2020.101368 32721872
# 35 Butler CA Adams GG Blum J et al Breastmilk influences development and composition of the oral microbiome J Oral Microbiol 2022 14 2096287 10.1080/20002297.2022.2096287 35832839
# 36 Haddad EN Sugino KY Kerver JM et al The infant gut microbiota at 12 months of age is associated with human milk exposure but not with maternal pre-pregnancy body mass index or infant BMI-for-age z-scores Curr Res Physiol 2021 4 94 102 10.1016/j.crphys.2021.03.004 34136830
# 37 Ahern GJ Hennessy AA Anthony Ryan C et al Advances in Infant Formula Science Annu Rev Food Sci Technol 2019 10 10.1146/ANNUREV-FOOD-081318-104308/CITE/REFWORKS
# 38 Sillner N Walker A Lucio M et al Longitudinal Profiles of Dietary and Microbial Metabolites in Formula- and Breastfed Infants Front Mol Biosci 2021 8 660456 10.3389/fmolb.2021.660456 34124150
# 39 Bridgman SL Azad MB Field CJ et al Fecal Short-Chain Fatty Acid Variations by Breastfeeding Status in Infants at 4 Months: Differences in Relative versus Absolute Concentrations Front Nutr 2017 4 11 10.3389/fnut.2017.00011 28443284
# 40 Tsukuda N Yahagi K Hara T et al Key bacterial taxa and metabolic pathways affecting gut short-chain fatty acid profiles in early life ISME J 2021 15 2574 90 10.1038/s41396-021-00937-7 33723382
# 41 Michaelsen KF Grummer-Strawn L Bégin F Emerging issues in complementary feeding: Global aspects Matern Child Nutr 2017 13 1 7 10.1111/mcn.12444
# 42 Chehab RF Cross TWL Forman MR The Gut Microbiota: A Promising Target in the Relation between Complementary Feeding and Child Undernutrition Adv Nutr 2021 12 969 79 10.1093/advances/nmaa146 33216115
# 43 Leong C Haszard JJ Lawley B et al Mediation Analysis as a Means of Identifying Dietary Components That Differentially Affect the Fecal Microbiota of Infants Weaned by Modified Baby-Led and Traditional Approaches Appl Environ Microbiol 2018 84 1 14 10.1128/AEM.00914-18
# 44 Differding MK Benjamin-Neelon SE Hoyo C et al Timing of complementary feeding is associated with gut microbiota diversity and composition and short chain fatty acid concentrations over the first year of life BMC Microbiol 2020 20 56 10.1186/s12866-020-01723-9 32160858
# 45 Galazzo G van Best N Bervoets L et al Development of the Microbiota and Associations With Birth Mode, Diet, and Atopic Disorders in a Longitudinal Analysis of Stool Samples, Collected From Infancy Through Early Childhood Gastroenterology 2020 158 1584 96 10.1053/j.gastro.2020.01.024 31958431
# 46 Baaleman DF Wegh CAM Leeuw TJM et al What are Normal Defecation Patterns in Healthy Children up to Four Years of Age: A Systematic Review and Meta-Analysis J Pediatr 2023 10.1016/J.JPEDS.2023.113559/ATTACHMENT/053C0ECE-77A0-4B96-9659-D60CA6CB3D80/MMC2.DOCX
# 47 Solasaari T Korpela K Lommi S et al Bowel function in a prospective cohort of 1052 healthy term infants up to 4 months of age Eur J Pediatr 2024 183 3557 65 10.1007/s00431-024-05625-0 38819500
# 48 Vandenplas Y Abkari A Bellaiche M et al Prevalence and Health Outcomes of Functional Gastrointestinal Symptoms in Infants From Birth to 12 Months of Age J Pediatr Gastroenterol Nutr 2015 61 531 7 10.1097/MPG.0000000000000949 26308317
# 49 Gatzinsky C Sillén U Thornberg S et al Bowel habits in healthy infants and the prevalence of functional constipation, infant colic and infant dyschezia Acta Paediatr 2023 112 1341 50 10.1111/apa.16736 36855830
# 50 Kashyap PC Marcobal A Ursell LK et al Complex interactions among diet, gastrointestinal transit, and gut microbiota in humanized mice Gastroenterology 2013 144 967 77 10.1053/j.gastro.2013.01.047 23380084
# 51 Roager HM Hansen LBS Bahl MI et al Colonic transit time is related to bacterial metabolism and mucosal turnover in the gut Nat Microbiol 2016 1 16093 10.1038/nmicrobiol.2016.93 27562254
# 52 Fernández-Reina A Urdiales JL Sánchez-Jiménez F What We Know and What We Need to Know about Aromatic and Cationic Biogenic Amines in the Gastrointestinal Tract Foods 2018 7 145 10.3390/foods7090145 30181486
# 53 Koh A De Vadder F Kovatcheva-Datchary P et al From Dietary Fiber to Host Physiology: Short-Chain Fatty Acids as Key Bacterial Metabolites Cell 2016 165 1332 45 10.1016/j.cell.2016.05.041 27259147
# 54 Bhattarai Y Williams BB Battaglioli EJ et al Gut Microbiota-Produced Tryptamine Activates an Epithelial G-Protein-Coupled Receptor to Increase Colonic Secretion Cell Host Microbe 2018 23 775 85 10.1016/j.chom.2018.05.004 29902441
# 55 Reigstad CS Salmonson CE Rainey JF 3rd et al Gut microbes promote colonic serotonin production through an effect of short-chain fatty acids on enterochromaffin cells FASEB J 2015 29 1395 403 10.1096/fj.14-259598 25550456
# 56 Chen H Nwe P-K Yang Y et al A Forward Chemical Genetic Screen Reveals Gut Microbiota Metabolites That Modulate Host Physiology Cell 2019 177 1217 31 10.1016/j.cell.2019.03.036 31006530
# 57 Husted AS Trauelsen M Rudenko O et al GPCR-Mediated Signaling of Metabolites Cell Metab 2017 25 777 96 10.1016/j.cmet.2017.03.008 28380372
# 58 Kalbermatter C Fernandez Trigo N Christensen S et al Maternal Microbiota, Early Life Colonization and Breast Milk Drive Immune Development in the Newborn Front Immunol 2021 12 683022 10.3389/fimmu.2021.683022 34054875
# 59 Sakurai T Odamaki T Xiao JZ Production of Indole-3-Lactic Acid by Bifidobacterium Strains Isolated fromHuman Infants Microorganisms 2019 7 340 10.3390/microorganisms7090340 31514325
# 60 Laursen MF Sakanaka M von Burg N et al Bifidobacterium species associated with breastfeeding produce aromatic lactic acids in the infant gut Nat Microbiol 2021 6 1367 82 10.1038/s41564-021-00970-4 34675385
# 61 Ehrlich AM Pacheco AR Henrick BM et al Indole-3-lactic acid associated with Bifidobacterium-dominated microbiota significantly decreases inflammation in intestinal epithelial cells BMC Microbiol 2020 20 357 10.1186/s12866-020-02023-y 33225894
# 62 Meng D Sommella E Salviati E et al Indole-3-lactic acid, a metabolite of tryptophan, secreted by Bifidobacterium longum subspecies infantis is anti-inflammatory in the immature intestine Pediatr Res 2020 88 209 17 10.1038/s41390-019-0740-x 31945773
# 63 Bisgaard H Li N Bonnelykke K et al Reduced diversity of the intestinal microbiota during infancy is associated with increased risk of allergic disease at school age J Allergy Clin Immunol 2011 128 646 52 10.1016/j.jaci.2011.04.060 21782228
# 64 Chiu C-Y Lin G Cheng M-L et al Longitudinal urinary metabolomic profiling reveals metabolites for asthma development in early childhood Pediatr Allergy Immunol 2018 29 496 503 10.1111/pai.12909 29679407
# 65 Singh R Chandrashekharappa S Bodduluri SR et al Enhancement of the gut barrier integrity by a microbial metabolite through the Nrf2 pathway Nat Commun 2019 10 89 10.1038/s41467-018-07859-7 30626868
# 66 Henrick BM Rodriguez L Lakshmikanth T et al Bifidobacteria-mediated immune system imprinting early in life Cell 2021 184 3884 98 10.1016/j.cell.2021.05.030 34143954
# 67 González S Selma-Royo M Arboleya S et al Levels of Predominant Intestinal Microorganisms in 1 Month-Old Full-Term Babies and Weight Gain during the First Year of Life Nutrients 2021 13 1 13 10.3390/nu13072412
# 68 Grier A Qiu X Bandyopadhyay S et al Impact of prematurity and nutrition on the developing gut microbiome and preterm infant growth Microbiome 2017 5 158 10.1186/s40168-017-0377-0 29228972
# 69 Alderete TL Jones RB Shaffer JP et al Early life gut microbiota is associated with rapid infant growth in Hispanics from Southern California Gut Microbes 2021 13 1961203 10.1080/19490976.2021.1961203 34424832
# 70 Uzan-Yulzari A Turta O Belogolovski A et al Neonatal antibiotic exposure impairs child growth during the first six years of life by perturbing intestinal microbial colonization Nat Commun 2021 12 443 10.1038/s41467-020-20495-4 33500411
# 71 Houtman TA Eckermann HA Smidt H et al Gut microbiota and BMI throughout childhood: the role of firmicutes, bacteroidetes, and short-chain fatty acid producers Sci Rep 2022 12 3140 10.1038/s41598-022-07176-6 35210542
# 72 Cowan CSM Dinan TG Cryan JF Annual Research Review: Critical windows - the microbiota-gut-brain axis in neurocognitive development J Child Psychol Psychiatry 2020 61 353 71 10.1111/jcpp.13156 31773737
# 73 Acuña I Cerdó T Ruiz A et al Infant Gut Microbiota Associated with Fine Motor Skills Nutrients 2021 13 1 13 10.3390/nu13051673
# 74 Sordillo JE Korrick S Laranjo N et al Association of the Infant Gut Microbiome With Early Childhood Neurodevelopmental Outcomes: An Ancillary Study to the VDAART Randomized Clinical Trial JAMA Netw Open 2019 2 e190905 10.1001/jamanetworkopen.2019.0905 30901046
# 75 Luk B Veeraragavan S Engevik M et al Postnatal colonization with human “infant-type” Bifidobacterium species alters behavior of adult gnotobiotic mice PLoS ONE 2018 13 e0196510 10.1371/journal.pone.0196510 29763437
# 76 Gao W Salzwedel AP Carlson AL et al Gut microbiome and brain functional connectivity in infants-a preliminary study focusing on the amygdala Psychopharmacology (Berl) 2019 236 1641 51 10.1007/s00213-018-5161-8 30604186
# 77 Kort R Schlösser J Vazquez AR et al Model Selection Reveals the Butyrate-Producing Gut Bacterium Coprococcus eutactus as Predictor for Language Development in 3-Year-Old Rural Ugandan Children Front Microbiol 2021 12 681485 10.3389/fmicb.2021.681485 34149673
# 78 Pärtty A Kalliomäki M Endo A et al Compositional development of Bifidobacterium and Lactobacillus microbiota is linked with crying and fussing in early infancy PLoS ONE 2012 7 e32495 10.1371/journal.pone.0032495 22403665
# 79 Loughman A Quinn T Nation ML et al Infant microbiota in colic: predictive associations with problem crying and subsequent child behavior J Dev Orig Health Dis 2021 12 260 70 10.1017/S2040174420000227 32279681
# 80 Schoch SF Castro-Mejía JL Krych L et al From Alpha Diversity to Zzz: Interactions among sleep, the brain, and gut microbiota in the first year of life Prog Neurobiol 2022 209 S0301-0082(21)00222-7 10.1016/j.pneurobio.2021.102208
# 81 Lewis SJ Heaton KW Stool form scale as a useful guide to intestinal transit time Scand J Gastroenterol 1997 32 920 4 10.3109/00365529709011203 9299672
# 82 Gustin J Gibb R Kenneally D et al Characterizing Exclusively Breastfed Infant Stool via a Novel Infant Stool Scale J Parenter Enteral Nutr 2018 42 S5 11 10.1002/jpen.1468
# 83 Bekkali N Hamers SL Reitsma JB et al Infant stool form scale: development and results J Pediatr 2009 154 521 6 10.1016/j.jpeds.2008.10.010 19054528
# 84 Nestel N Hvass JD Bahl MI et al The Gut Microbiome and Abiotic Factors as Potential Determinants of Postprandial Glucose Responses: A Single-Arm Meal Study Front Nutr 2020 7 594850 10.3389/fnut.2020.594850 33585532
# 85 Sadeh A A brief screening questionnaire for infant sleep problems: validation and findings for an Internet sample Pediatrics 2004 113 e570 7 10.1542/peds.113.6.e570 15173539
# 86 Ammitzbøll J Holstein BE Wilms L et al A new measure for infant mental health screening: development and initial validation BMC Pediatr 2016 16 197 10.1186/s12887-016-0744-1 27905887
# 87 Wijnhoven TM de Onis M Onyango AW et al Assessment of gross motor development in the WHO Multicentre Growth Reference Study Food Nutr Bull 2004 25 S37 45 10.1177/15648265040251S105 15069918
# 88 Wang S Zeng S Egan M et al Metagenomic analysis of mother-infant gut microbiome reveals global distinct and shared microbial signatures Gut Microbes 2021 13 1 24 1911571 10.1080/19490976.2021.1911571
# 89 Laursen MF Sakanaka M von Burg N et al Breastmilk-promoted bifidobacteria produce aromatic amino acids in the infant gut Microbiology Preprint 2020 10.1101/2020.01.22.914994
# 90 Allen LH Hampel D Shahab-Ferdows S et al The Mothers, Infants, and Lactation Quality (MILQ) Study: A Multi-Center Collaboration Curr Dev Nutr 2021 5 nzab116 10.1093/cdn/nzab116 34712893
# 91 Bergström A Skov TH Bahl MI et al Establishment of intestinal microbiota during early life: a longitudinal, explorative study of a large cohort of Danish infants Appl Environ Microbiol 2014 80 2889 900 10.1128/AEM.00342-14 24584251
# 92 Hill CJ Lynch DB Murphy K et al Evolution of gut microbiota composition from birth to 24 weeks in the INFANTMET Cohort Microbiome 2017 5 10.1186/s40168-016-0213-y
# 93 Laursen MF Sinha AK Pedersen M et al Key bacterial taxa determine longitudinal dynamics of aromatic amino acid catabolism in infants’ gut Gut Microbes 2023 15 2221426 10.1080/19490976.2023.2221426 37357437

# %%
SEARCH_TERM
# Out:
# '(("oral"[tiab] OR "saliva"[tiab] OR "salivary"[tiab] OR "dental plaque"[tiab] OR "gingival"[tiab] OR "periodontal"[tiab] OR "subgingival"[tiab] OR "supragingival"[tiab]) AND ("microbiome"[Title/Abstract] OR "microbiota"[Title/Abstract] OR "microflora"[Title/Abstract] OR "dysbiosis"[Title/Abstract])) AND (ffrft[Filter]) NOT (Review[PT] OR Editorial[PT] OR Letter[PT] OR Comment[PT] OR Case Reports[PT])'

# %%
class Article():
  def __init__(self, article) -> None:
      self.author=''
      self.name=''
      self.environment=''
      self.study_link=''
      self.study_title=''
      self.year=''
      self.country=''
      self.sequencing_type=''
      self.sequencing_quote=''
      self.accession_code=''
      self.metadata_present=''
      self.sample_id_matches=''
      self.sra_name_present=''
      self.sra_name_example=''
      self.pmc=''
      self.notes=''
      self.questions=''
      self.article_type=''
      self.abstract=''

  def get_country():
    pass

  def get_sequencing_type():
    pass

  def get_sequencing_quote():
    pass

  def get_article_type():
    pass

# %%
print(llm_search_for_accession(tt))
# Out:
# HTTPS://TP.AMEGROUPS.COM/ARTICLE/VIEW/10.21037/TP-2024-571/DSS

# %%
qq
# Out:
# ['PRJNA1240943', 'PRJNA1229416']

# %%
df
# Out:
#         author1author2Year        YourName Environment  \
# 0           ZhangZhang2025  DmitryKisselev        oral
# 1           JarrettXia2025  DmitryKisselev        oral
# 2            GongHuang2025  DmitryKisselev        oral
# 3    MavropoulosZaiton2025  DmitryKisselev        oral
# 4   Saberi kakhkiHarks2025  DmitryKisselev        oral
# ..                     ...             ...         ...
# 95          HuangHuang2025  DmitryKisselev        oral
# 96         ShanshanShu2025  DmitryKisselev        oral
# 97        SiddiquiTsai2025  DmitryKisselev        oral
# 98      CortizoCasarin2025  DmitryKisselev        oral
# 99               WuShi2025  DmitryKisselev        oral
#
#                                     StudyLink  \
# 0   https://pubmed.ncbi.nlm.nih.gov/40525871/
# 1   https://pubmed.ncbi.nlm.nih.gov/40525692/
# 2   https://pubmed.ncbi.nlm.nih.gov/40525407/
# 3   https://pubmed.ncbi.nlm.nih.gov/40524744/
# 4   https://pubmed.ncbi.nlm.nih.gov/40524743/
# ..                                        ...
# 95  https://pubmed.ncbi.nlm.nih.gov/40458824/
# 96  https://pubmed.ncbi.nlm.nih.gov/40458807/
# 97  https://pubmed.ncbi.nlm.nih.gov/40458201/
# 98  https://pubmed.ncbi.nlm.nih.gov/40457720/
# 99  https://pubmed.ncbi.nlm.nih.gov/40457573/
#
#                                            StudyTitle  Year        Country  \
# 0   Will gut, oral, and vaginal microbiota influen...  2025          China
# 1   Characterizing Microbiome Changes in Veno-Veno...  2025            USA
# 2   Combination of mitomycin C and low-dose metron...  2025         Taiwan
# 3     Rapid Griess assay (RGA): a chairside test for   2025         Sweden
# 4   Association of supragingival plaque management...  2025        Germany
# ..                                                ...   ...            ...
# 95  Therapeutic efficacy of fecal microbiota trans...  2025          China
# 96  Modulating the gut microbiota and inflammation...  2025          China
# 97  Utilizing a naturopathic mouthwash with select...  2025  United States
# 98  Microbiome and Metaproteome of Craniofacial Im...  2025         Brazil
# 99  Correction to "Oral Administration of Bioactiv...  2025            USA
#
#       SequencingType                                    SequencingQuote  \
# 0   Prediction Error  Error: ('Connection aborted.', RemoteDisconnec...
# 1                16S  "Specimens underwent 16S sequencing to identif...
# 2        No Abstract
# 3            Unknown
# 4                16S  "Subgingival microbiota were profiled via Illu...
# ..               ...                                                ...
# 95           Unknown
# 96           Unknown
# 97           Unknown
# 98               16S  "Microbiome profiling was conducted through DN...
# 99       No Abstract
#
#    AccessionCode  ... SampleIDmatches? SRAnamePresent SRAnameExample  \
# 0                 ...
# 1                 ...
# 2                 ...
# 3                 ...
# 4                 ...
# ..           ...  ...              ...            ...            ...
# 95                ...
# 96                ...
# 97                ...
# 98                ...
# 99                ...
#
#             PMC Notes Questions               Type  \
# 0          None                  Original Research
# 1          None                  Original Research
# 2          None                            Unknown
# 3   PMC12168414                  Original Research
# 4   PMC12168411                   Prediction Error
# ..          ...   ...       ...                ...
# 95  PMC12127135                  Original Research
# 96  PMC12127415                  Original Research
# 97  PMC12127372                  Original Research
# 98         None                  Original Research
# 99         None                            Unknown
#
#                                              Abstract        S3_Bucket  \
# 0   This study aims to examine the specific relati...             None
# 1   Microbiome analysis using metagenomics next-ge...             None
# 2                                                                 None
# 3   Nitrite (NO\nFrom 12 healthy individuals, tong...             None
# 4   This study examines the relationship between s...             None
# ..                                                ...              ...
# 95  This report presents the first documented appl...  pmc-oa-opendata
# 96  Diabetic nephropathy (DN) is a severe complica...  pmc-oa-opendata
# 97  Oral rinses intended for the prevention and tr...  pmc-oa-opendata
# 98  Craniofacial defects from cancer surgery led t...             None
# 99                                               None             None
#
#                       S3_Object_Key
# 0                              None
# 1                              None
# 2                              None
# 3                              None
# 4                              None
# ..                              ...
# 95  oa_comm/txt/all/PMC12127135.txt
# 96  oa_comm/txt/all/PMC12127415.txt
# 97  oa_comm/txt/all/PMC12127372.txt
# 98                             None
# 99                             None
#
# [100 rows x 21 columns]

# %%
df.to_csv('tt.csv')

# %%
df.at[indx,'SequencingType']
# Out:
# 'Shotgun'

# %%
predict_sequencing_type_and_quote(df['Abstract'][18])
# Out:
# ('16S',
#  '"The use of antimicrobials reduced ... bacterial diversity, and genera such as Blautia and Turicibacter."')

# %%
predict_sequencing_type_and_quote(df['Abstract'][18])
# Out:
# ('Shotgun', '"This modulation promoted BA production"')

# %%
df
# Out:
#         author1author2Year        YourName Environment  \
# 0           ZhangZhang2025  DmitryKisselev        oral
# 1           JarrettXia2025  DmitryKisselev        oral
# 2            GongHuang2025  DmitryKisselev        oral
# 3    MavropoulosZaiton2025  DmitryKisselev        oral
# 4   Saberi kakhkiHarks2025  DmitryKisselev        oral
# ..                     ...             ...         ...
# 95          HuangHuang2025  DmitryKisselev        oral
# 96         ShanshanShu2025  DmitryKisselev        oral
# 97        SiddiquiTsai2025  DmitryKisselev        oral
# 98      CortizoCasarin2025  DmitryKisselev        oral
# 99               WuShi2025  DmitryKisselev        oral
#
#                                     StudyLink  \
# 0   https://pubmed.ncbi.nlm.nih.gov/40525871/
# 1   https://pubmed.ncbi.nlm.nih.gov/40525692/
# 2   https://pubmed.ncbi.nlm.nih.gov/40525407/
# 3   https://pubmed.ncbi.nlm.nih.gov/40524744/
# 4   https://pubmed.ncbi.nlm.nih.gov/40524743/
# ..                                        ...
# 95  https://pubmed.ncbi.nlm.nih.gov/40458824/
# 96  https://pubmed.ncbi.nlm.nih.gov/40458807/
# 97  https://pubmed.ncbi.nlm.nih.gov/40458201/
# 98  https://pubmed.ncbi.nlm.nih.gov/40457720/
# 99  https://pubmed.ncbi.nlm.nih.gov/40457573/
#
#                                            StudyTitle  Year        Country  \
# 0   Will gut, oral, and vaginal microbiota influen...  2025          China
# 1   Characterizing Microbiome Changes in Veno-Veno...  2025            USA
# 2   Combination of mitomycin C and low-dose metron...  2025         Taiwan
# 3   Rapid Griess assay (RGA): a chairside test for...  2025         Sweden
# 4   Association of supragingival plaque management...  2025        Germany
# ..                                                ...   ...            ...
# 95  Therapeutic efficacy of fecal microbiota trans...  2025          China
# 96  Modulating the gut microbiota and inflammation...  2025          China
# 97  Utilizing a naturopathic mouthwash with select...  2025  United States
# 98  Microbiome and Metaproteome of Craniofacial Im...  2025         Brazil
# 99  Correction to "Oral Administration of Bioactiv...  2025            USA
#
#    SequencingType                                    SequencingQuote  \
# 0         Unknown  "The underlying mechanism was furtherly confir...
# 1             16S  "Specimens underwent 16S sequencing to identif...
# 2     No Abstract
# 3         Unknown
# 4             16S  "Subgingival microbiota were profiled via Illu...
# ..            ...                                                ...
# 95        Unknown
# 96        Unknown
# 97        Unknown
# 98            16S  "Microbiome profiling was conducted through DN...
# 99    No Abstract
#
#    AccessionCode  ... SRAnameExample          PMC Notes Questions  \
# 0                 ...                        None
# 1                 ...                        None
# 2                 ...                        None
# 3                 ...                 PMC12168414
# 4                 ...                 PMC12168411
# ..           ...  ...            ...          ...   ...       ...
# 95                ...                 PMC12127135
# 96                ...                 PMC12127415
# 97                ...                 PMC12127372
# 98                ...                        None
# 99                ...                        None
#
#                  Type                                           Abstract  \
# 0   Original Research  This study aims to examine the specific relati...
# 1   Original Research  Microbiome analysis using metagenomics next-ge...
# 2             Unknown
# 3   Original Research  Nitrite (NO\nFrom 12 healthy individuals, tong...
# 4    Prediction Error  This study examines the relationship between s...
# ..                ...                                                ...
# 95  Original Research  This report presents the first documented appl...
# 96  Original Research  Diabetic nephropathy (DN) is a severe complica...
# 97  Original Research  Oral rinses intended for the prevention and tr...
# 98  Original Research  Craniofacial defects from cancer surgery led t...
# 99            Unknown                                               None
#
#           S3_Bucket                    S3_Object_Key Regex_Accession_Codes  \
# 0              None                             None
# 1              None                             None
# 2              None                             None
# 3              None                             None
# 4              None                             None
# ..              ...                              ...                   ...
# 95  pmc-oa-opendata  oa_comm/txt/all/PMC12127135.txt
# 96  pmc-oa-opendata  oa_comm/txt/all/PMC12127415.txt
# 97  pmc-oa-opendata  oa_comm/txt/all/PMC12127372.txt
# 98             None                             None
# 99             None                             None
#
#                           LLM_Accession_Search_Status
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 95  HTTPS://WWW.FRONTIERSIN.ORG/ARTICLES/10.3389/F...
# 96                           NO RELEVANT INFORMATION.
# 97  HTTPS://WWW.FRONTIERSIN.ORG/ARTICLES/10.3389/F...
# 98                                               None
# 99                                               None
#
# [100 rows x 23 columns]

# %%
print(df['StudyTitle'][29])
# Out:
# Roseburia intestinalis Modulates Immune Responses by Inducing M1 Macrophage Polarization.

# %%
get_clean_article_title_from_xml(articles[29].xml)
# Out:
# <Element 'ArticleTitle' at 0x7974178e4810>
# Roseburia intestinalis Modulates Immune Responses by Inducing M1 Macrophage Polarization.
# 'N/A'

# %%
find_accession_codes_in_text(tt1)
# Out:
# ['PRJEB76179']

# %%
tt1=get_s3_file_content(buck[0],buck[1])

# %%
buck=check_pmc_file_in_s3('PMC12168284')
# Out:
# Checking s3://pmc-oa-opendata/oa_noncomm/txt/all/PMC12168284.txt
# Checking s3://pmc-oa-opendata/oa_comm/txt/all/PMC12168284.txt

# %%
tt1[0:100]
# Out:
# '\n==== Front\nMicrobiome\nMicrobiome\nMicrobiome\n2049-2618\nBioMed Central London\n\n2123\n10.1186/s40168-02'

# %%
buck[1]
# Out:
# 'oa_comm/txt/all/PMC12168284.txt'

# %%
llm_search_for_accession(tt1)
# Out:
# 'ACCESSION CODES: PRJEB76179\nURL: HTTPS://GITHUB.COM/AEMANN01/LONG_ORAL_MICROBIOME'
