# %% [markdown]
# <a href="https://colab.research.google.com/github/dkisselev-zz/mmc-pipeline/blob/main/Get_Sample_MetaData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ok# -*- coding: utf-8 -*-
"""
## Notebook: SRA and BioSample Metadata Extraction from Google Sheet

This notebook takes a list of SRA/BioProject accession codes from a specified
Google Sheet, queries the NCBI Entrez E-Utilities API, and extracts detailed
metadata for each entry.

It gathers information about the SRA records (like instrument and library names)
and the associated BioSample records (like host organism).
"""

# ==============================================================================
# STEP 1: SETUP (IMPORTS AND AUTHENTICATION)
# ==============================================================================
import os
import io
import requests
import time
import re
import json
import pandas as pd
from ftplib import FTP
from collections import defaultdict
import xml.etree.ElementTree as ET
from google.colab import auth
from google.auth import default
import google.generativeai as genai
from google.colab import userdata
from google.colab.data_table import DataTable
import gspread

# --- Authenticate to access Google Sheet ---
# This will prompt you to log in and authorize access.
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

print("Authentication successful.")
# Out:
# Authentication successful.

# %% [markdown]
# ### Step 2

# %%
# ==============================================================================
# STEP 2: LLM NORMALIZER AND CORE NCBI DATA FUNCTION
# ==============================================================================
# --- LLM Class for Host Normalization ---
class LLMNormalizer:
    def __init__(self):
        try:
            API_KEY = userdata.get('GOOGLE_API_KEY')
            genai.configure(api_key=API_KEY)
            self.model = genai.GenerativeModel("gemini-1.5-flash")
            print("LLM Normalizer initialized successfully.")
        except Exception as e:
            print(f"ERROR: Could not initialize LLM. Normalization will be skipped. Details: {e}")
            self.model = None

    def _call_gemini_with_retries(self, prompt, retries=3, delay=5):
        if not self.model: return "LLM Not Initialized"
        for attempt in range(retries):
            try:
                # Request JSON output from the model
                response = self.model.generate_content(prompt, generation_config={"response_mime_type": "application/json"})
                return response.text.strip()
            except Exception as e:
                print(f"  > LLM Error (Attempt {attempt + 1}/{retries}): {e}")
                if attempt < retries - 1:
                    time.sleep(delay)
                else: return "{}" # Return empty JSON on failure

    def create_host_normalization_map(self, host_list):
        if not self.model or not host_list: return {}

        unique_hosts = sorted(list(set(h.strip() for h in host_list if h and h.strip())))

        prompt= (
                """You are a bioinformatics expert tasked with cleaning data. Your job is to analyze the following JSON list of
                   host names and standardize them according to these strict rules.

                ## Core Principle:
                Your primary goal is to identify the **source organism** for each item.

                ## Rules:
                1.  **The Host Extraction Rule:** If an input string names a host organism (e.g., 'human', 'mouse', 'rat', 'bovine') and describes a sample taken from it (e.g., '...milk metagenome', '...gut', '...oral metagenome'), your output **MUST BE** the scientific name of that host organism. **Completely ignore the specific sample type** (milk, oral, skin, feces, etc.) in the output value. The value must *only* be the scientific name.
                2.  **The Null Value Rule:** For inputs like 'not applicable', 'not collected', 'N/A', or 'missing', the value **MUST** be the JSON literal `null`.
                3.  **The Consolidation Rule:** Consolidate all variations, common names, and strains to the main scientific name (e.g., 'C57 mice', 'mice1', 'C57BL/6' must all become *Mus musculus*).
                4.  **The Environmental Rule:** For environmental samples without a clear host (e.g., 'soil metagenome', 'aquatic metagenome'), use the original string as the value.

                ## Crucial Examples (Follow this logic precisely):
                -   `"human milk metagenome": "Homo sapiens"`
                -   `"human oral metagenome": "Homo sapiens"`
                -   `"human reproductive system metagenome": "Homo sapiens"`
                -   `"bovine metagenome": "Bos taurus"`
                -   `"Bradyrhizobium sp. W001": "Bradyrhizobium"`
                -   `"rat gut metagenome": "Rattus norvegicus"`
                -   `"human-associated": "Homo sapiens"`
                -   `"not collected": null`
                -   `"C57BL/6": "Mus musculus"`
                -   `"Rhizosphere rep 1": "soil metagenome"`
                -   `"soil metagenome": "soil metagenome"`

                ## Output Format:
                Your response must be ONLY a single, valid JSON object that maps each original name from the input list to its corrected, standardized version. Do not include any other text, explanations, or markdown formatting.

                Here is the list of hosts:\n"""
                f"{json.dumps(unique_hosts)}"
        )

        try:
            response_text = self._call_gemini_with_retries(prompt)
            # Clean the response to ensure it's valid JSON
            clean_json_text = response_text.strip().lstrip("```json").rstrip("```")
            normalization_map = json.loads(clean_json_text)
            return normalization_map
        except json.JSONDecodeError as e:
            print(f"  > LLM returned invalid JSON, cannot create normalization map. Error: {e}")
            return {}
        except Exception as e:
            print(f"  > An unexpected error occurred during LLM normalization: {e}")
            return {}

# --- API Request Helper ---
def make_request_with_retries(method, url, data=None, retries=3):

    for attempt in range(retries):
        try:
            if method.upper() == 'POST':
                response = requests.post(url, data=data)
            else:
                response = requests.get(url)
            if response.status_code in [429, 500, 502, 503, 504]:
                wait_time = 5 * (attempt + 1)
                print(f"  > WARNING: Received status {response.status_code}. Retrying in {wait_time} seconds...")
                time.sleep(wait_time)
                continue
            response.raise_for_status()
            return response
        except requests.exceptions.RequestException as e:
            print(f"  > ERROR: Request failed on attempt {attempt + 1}: {e}")
            if attempt < retries - 1: time.sleep(5 * (attempt + 1))
            else: return None
    return None

def get_cngb_details(accession_code: str):
    """
    Fetches project metadata from CNGBdb using the FTP protocol. This version
    derives the experiment count from the metadata file itself for better accuracy.
    """
    print(f"Fetching CNGBdb data for {accession_code}...")
    details = {'AccessionCode': accession_code}
    ftp = None

    try:
        # --- Connect to the FTP server and dynamically find files ---
        ftp_host = "ftp2.cngb.org"
        ftp_path = f"/pub/CNSA/data7/public_info/{accession_code}/"

        print(f"  > Connecting to FTP server: {ftp_host}")
        ftp = FTP(ftp_host)
        ftp.login()
        ftp.cwd(ftp_path)

        filenames = ftp.nlst()
        print(f"  > Found {len(filenames)} files in directory.")

        experiment_file_name = None
        sample_file_name = None

        for f in filenames:
            if 'experiment' in f.lower() and f.endswith('.tsv'):
                experiment_file_name = f
            if 'sample' in f.lower() and f.endswith('.tsv'):
                sample_file_name = f

        if not experiment_file_name or not sample_file_name:
            print(f"  > ERROR: Could not find both experiment and sample .tsv files in the directory.")
            return details

        # --- Download files into memory and read with pandas ---
        print(f"  > Found experiment file: {experiment_file_name}")
        exp_bio = io.BytesIO()
        ftp.retrbinary(f'RETR {experiment_file_name}', exp_bio.write)
        exp_bio.seek(0)
        exp_df = pd.read_csv(exp_bio, sep='\t', on_bad_lines='skip')

        print(f"  > Found sample file: {sample_file_name}")
        sample_bio = io.BytesIO()
        ftp.retrbinary(f'RETR {sample_file_name}', sample_bio.write)
        sample_bio.seek(0)
        sample_df = pd.read_csv(sample_bio, sep='\t', on_bad_lines='skip')

        # --- Get the experiment count directly from the DataFrame length ---
        details['Number of Experiments'] = len(exp_df)

        # Extract and format the data
        details['All Experiments IDs'] = '; '.join(sorted(list(set(exp_df['experiment_accession'].dropna()))))
        details['SRA Name'] = '; '.join(sorted(list(set(exp_df['sample_name'].dropna()))))
        details['Library Name'] = '; '.join(sorted(list(set(exp_df['library_name'].dropna()))))

        combined_instruments = (exp_df['platform'].fillna('') + ' ' + exp_df['instrument_model'].fillna('')).str.strip()
        details['Instrument Name'] = '; '.join(sorted(list(set(combined_instruments.dropna()))))

        unique_biosamples = sorted(list(set(sample_df['sample_accession'].dropna())))
        details['BioSample Accession'] = '; '.join(unique_biosamples)
        details['Sample Title'] = '; '.join(sorted(list(set(sample_df['sample_title'].dropna()))))
        details['SRA Host'] = '; '.join(sorted(list(set(sample_df['host'].dropna()))))

        # Extract all BioSample attributes
        attr_df = sample_df.drop(columns=['sample_accession', 'sample_name', 'sample_title'], errors='ignore')
        details['All Attribute Keys'] = '; '.join(sorted(attr_df.columns))

        all_attributes = defaultdict(list)
        for col in attr_df.columns:
            all_attributes[col].extend(attr_df[col].dropna().unique().tolist())

        details['BioSampleAttributes'] = {key: sorted(list(set(values))) for key, values in all_attributes.items()}

        print(f"  > Successfully processed {accession_code}.")
        return details

    except Exception as e:
        print(f"  > An unexpected critical error occurred for {accession_code}: {e}")
        return { 'AccessionCode': accession_code, 'Error': str(e) }
    finally:
        # Ensure the FTP connection is always closed
        if ftp:
            ftp.quit()
            print("  > FTP connection closed.")

def get_ngdc_details(accession_code: str):
    """
    Fetches and parses project metadata from the China National Genomics
    Data Center (NGDC) for a given PRJCA accession.
    """
    print(f"Fetching NGDC data for {accession_code}...")
    details = {'AccessionCode': accession_code}

    try:
        # Get Project Title from the BioProject API
        project_api_url = f"https://ngdc.cncb.ac.cn/gwh/api/public/bioProject/{accession_code}"
        project_response = make_request_with_retries('GET', project_api_url)
        if not project_response: return details

        project_data = project_response.json()
        details['SRA Name'] = project_data.get('title', 'N/A')

        # 2. Scrape the HTML browse page to get the sample count and all sample accessions
        browse_url = f"https://ngdc.cncb.ac.cn/bioproject/browse/{accession_code}"
        print(f"  > Scraping for sample list: {browse_url}")
        browse_response = make_request_with_retries('GET', browse_url)
        if not browse_response: return details

        html_content = browse_response.text
        # Extract sample count
        count_match = re.search(r"BioSample\s*\((\d+)\)", html_content)
        details['Number of Experiments'] = int(count_match.group(1)) if count_match else 0

        # Extract all sample accessions (e.g., SAMC#######)
        sample_ids = re.findall(r'/browse/(SAMC\d+)', html_content)
        unique_biosamples = sorted(list(set(sample_ids)))
        details['BioSample Accession'] = '; '.join(unique_biosamples)
        print(f"  > Found {len(unique_biosamples)} unique BioSample accessions.")

        if not unique_biosamples:
            return details

        # For each BioSample, query its API to get detailed metadata
        all_exp_ids, all_lib_names, all_inst_names, all_sample_titles, all_sra_hosts = [], [], [], [], []
        all_attributes = defaultdict(list)

        for i, sample_id in enumerate(unique_biosamples):
            print(f"\r  > Processing sample {i+1}/{len(unique_biosamples)}: {sample_id}", end="")
            sample_api_url = f"https://ngdc.cncb.ac.cn/gwh/api/public/bioSample/{sample_id}"
            sample_response = make_request_with_retries('GET', sample_api_url)
            if not sample_response: continue

            sample_data = sample_response.json()

            # Collect sample-level info
            if (st := sample_data.get('name')): all_sample_titles.append(st)
            if (host := sample_data.get('sampleAttribute',{}).get('hostTaxon', {}).get('name')): all_sra_hosts.append(host)

            # Collect attributes

            attributes_dict = sample_data.get('sampleAttribute', {})
            for attrName, attrValue in attributes_dict.items():
                if attrValue is not None:
                    all_attributes[attrName]=attrValue

            # Collect experiment-level info from within the sample data
            # for exp in sample_data.get('experiments', []):
            #     if (eid := exp.get('experimentAccession')): all_exp_ids.append(eid)
            #     if (ln := exp.get('libraryName')): all_lib_names.append(ln)
            #     # NGDC provides 'platform', which we'll use for Instrument Name
            #     if (im := exp.get('platform')): all_inst_names.append(im)

            # time.sleep(0.1) # Small delay to be polite to the server
            # break
        print("\n  > Sample processing complete.")

        # Aggregate and format all collected data
        details['All Experiments IDs'] = ''
        details['Library Name'] = ''
        details['Instrument Name'] = ''
        details['Sample Title'] = '; '.join(sorted(list(set(all_sample_titles))))
        details['SRA Host'] = '; '.join(sorted(list(set(all_sra_hosts))))

        details['All Attribute Keys'] = '; '.join(sorted(all_attributes.keys()))
        details['BioSampleAttributes'] = '; '.join(sorted(set([f"{key}: {values}" for key, values in all_attributes.items()])))

        print(f"  > Successfully processed {accession_code}.")
        return details

    except Exception as e:
        print(f"  > An unexpected critical error occurred for {accession_code}: {e}")
        return { 'AccessionCode': accession_code, 'Error': str(e) }

# --- Main Data Fetching Function (Corrected Signature) ---
def get_sra_and_biosample_details(accession_code: str):
    """
    Main router function. Checks the accession prefix and calls the appropriate
    function for either NCBI or CNGBdb.
    """
    # Define valid prefixes for both repositories
    NCBI_PREFIXES = ('PRJDB','PRJNA', 'PRJEB', 'SRP', 'E-MTAB', 'ERA', 'ERP', 'DRP', 'DRA', 'DRX', 'SAMN', 'SRX', 'SRR', 'PHS')
    CNGB_PREFIXES = ('CNP',)
    NGDC_PREFIXES = ('PRJCA',)

    # --- ROUTER LOGIC ---
    if isinstance(accession_code, str):
        upper_accession = accession_code.upper()
        if upper_accession.startswith(NCBI_PREFIXES):
            return get_ncbi_details(accession_code)
        elif upper_accession.startswith(CNGB_PREFIXES):
            return get_cngb_details(accession_code)
        elif upper_accession.startswith(NGDC_PREFIXES):
            # Route to the new NGDC function
            return get_ngdc_details(accession_code)

    # If it's not a supported format, skip it
    print(f"Skipping invalid or unsupported accession format: {accession_code}")
    return {}


def get_ncbi_details(accession_code: str):
    """
    Main function to query NCBI. This version only fetches raw data and has no
    dependency on the LLM normalizer.
    """

    main_accession = accession_code.split(',')[0].strip()
    details = { 'AccessionCode': accession_code }
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/"

    try:
        # Step 1: Get experiment count and all internal IDs
        print(f"Fetching SRA data for {main_accession}...")
        esearch_url = f"{base_url}esearch.fcgi?db=sra&term={main_accession}"
        time.sleep(0.4)
        response = make_request_with_retries('GET', esearch_url)
        if not response: return details
        root = ET.fromstring(response.content)
        count = int(root.find('.//Count').text)
        details['Number of Experiments'] = count
        print(f"  > Experiments found {count}")
        if count == 0:
            print(f"  > No experiments found for {main_accession}.")
            return details

        esearch_all_ids_url = f"{base_url}esearch.fcgi?db=sra&term={main_accession}&retmax={count}"
        all_ids_response = make_request_with_retries('GET', esearch_all_ids_url)
        if not all_ids_response: return details
        all_ids_list = [elem.text for elem in ET.fromstring(all_ids_response.content).findall('.//Id')]

        # Step 2: Fetch SRA metadata in batches
        all_sra_data = []
        chunk_size = 200
        for i in range(0, len(all_ids_list), chunk_size):
            chunk = all_ids_list[i:i + chunk_size]
            print(f"  > Fetching SRA metadata for batch {i//chunk_size + 1}...")
            post_data = {'db': 'sra', 'id': ','.join(chunk), 'retmode': 'xml'}
            efetch_response = make_request_with_retries('POST', f"{base_url}efetch.fcgi", data=post_data)
            if efetch_response: all_sra_data.append(ET.fromstring(efetch_response.content))

        # Step 3: Parse aggregated SRA data
        all_exp_ids, all_titles, all_lib_names, all_inst_names, all_sample_titles, all_biosample_accs = [], [], [], [], [], []
        for sra_root in all_sra_data:
            for exp in sra_root.findall('.//EXPERIMENT'):
                if (eid := exp.find('./IDENTIFIERS/PRIMARY_ID')) is not None and eid.text: all_exp_ids.append(eid.text.strip())
                if (t := exp.find('./TITLE')) is not None and t.text: all_titles.append(t.text.strip())
                if (ln := exp.find('.//LIBRARY_NAME')) is not None and ln.text: all_lib_names.append(ln.text.strip())
                if (im := exp.find('.//INSTRUMENT_MODEL')) is not None and im.text: all_inst_names.append(im.text.strip())
            for sample in sra_root.findall('.//SAMPLE'):
                if (st := sample.find('./TITLE')) is not None and st.text: all_sample_titles.append(st.text.strip())
                for ext_id in sample.findall('.//EXTERNAL_ID'):
                    if ext_id.get('namespace') == 'BioSample' and ext_id.text: all_biosample_accs.append(ext_id.text.strip())

        details['All Experiments IDs'] = '; '.join(sorted(list(set(all_exp_ids))))
        details['SRA Name'] = '; '.join(sorted(list(set(all_titles))))
        details['Library Name'] = '; '.join(sorted(list(set(all_lib_names))))
        details['Instrument Name'] = '; '.join(sorted(list(set(all_inst_names))))
        details['Sample Title'] = '; '.join(sorted(list(set(all_sample_titles))))
        unique_biosamples = sorted(list(set(all_biosample_accs)))
        details['BioSample Accession'] = '; '.join(unique_biosamples)

        # Step 4: Fetch BioSample attributes and store them raw
        if unique_biosamples:
            print(f"  > Found {len(unique_biosamples)} unique BioSamples. Fetching all raw attributes...")
            all_attributes = defaultdict(list)
            for i in range(0, len(unique_biosamples), chunk_size):
                chunk = unique_biosamples[i:i + chunk_size]
                post_data = {'db': 'biosample', 'id': ','.join(chunk), 'retmode': 'xml'}
                biosample_response = make_request_with_retries('POST', f"{base_url}efetch.fcgi", data=post_data)
                if not biosample_response: continue
                for biosample in ET.fromstring(biosample_response.content).findall('BioSample'):
                    for attr in biosample.findall('.//Attribute'):
                        if (attr_name := attr.get('attribute_name')) and attr.text:
                            all_attributes[attr_name].append(attr.text.strip())

            details['SRA Host'] = '; '.join(sorted(list(set(all_attributes.get('host', [])))))
            details['All Attribute Keys'] = '; '.join(sorted(all_attributes.keys()))
            details['BioSampleAttributes'] = {key: sorted(list(set(values))) for key, values in all_attributes.items()}

        print(f"  > Successfully processed {main_accession}.")
        return details

    except Exception as e:
        print(f"  > An unexpected critical error occurred for {main_accession}: {e}")
        return { 'AccessionCode': accession_code, 'Error': str(e) }

# %% [markdown]
# ### Step 3

# %%
# ==============================================================================
# STEP 3: LOAD DATA FROM GOOGLE SHEET
# ==============================================================================

# --- Load the full, current dataset from Google Sheets ---
print("--- Loading data from Google Sheet ---")

# --- Open the spreadsheet and the specific sheet by name ---
spreadsheet_url = 'https://docs.google.com/spreadsheets/d/1tBjpV_GoXIjx4_3o73Qml0h-BzFBZTD5bc3QHx1l1_4'
spreadsheet = gc.open_by_url(spreadsheet_url)
worksheet = spreadsheet.worksheet("Main Data Sheet")

# --- Manually read the data to handle the header on the second row ---
all_values = worksheet.get_all_values()

# The header is the second row (index 1), and the data starts from the third row (index 2)
header = all_values[1]
data_rows = all_values[2:2349]

# --- Convert the lists to a pandas DataFrame --
main_data_sheet = pd.DataFrame(data_rows, columns=header)

# --- Reset the index to ensure it is unique and clean ---
# main_data_sheet.reset_index(drop=True, inplace=True)

# Clean up the DataFrame: remove rows where 'AccessionCode' is empty
# main_data_sheet = main_data_sheet[main_data_sheet['AccessionCode'] != ''].copy()
print(f"Loaded {len(main_data_sheet)} total records from Google Sheet.")

# --- Identify new records by checking against a saved list of processed accessions ---
new_rows_to_process = pd.DataFrame()

# Filter for rows that are not in the processed list
new_rows_to_process = main_data_sheet[main_data_sheet['Number of Experiments']==""]

print(f"Found {len(new_rows_to_process)} new records to process.")

print("\n--- Successfully loaded data from Google Sheet ---")

# Display the first few rows of the loaded data
DataTable(new_rows_to_process.head())
# Out:
# --- Loading data from Google Sheet ---
# Loaded 2347 total records from Google Sheet.
# Found 1087 new records to process.
#
# --- Successfully loaded data from Google Sheet ---
# Warning: Total number of columns (66) exceeds max_columns (20) limiting to first (20) columns.
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Author1Author2name (LastName1LastName2)</th>
#       <th>Has someone done this study?</th>
#       <th>YourName</th>
#       <th>Host</th>
#       <th>Environment</th>
#       <th>StudyLink</th>
#       <th>StudyTitle</th>
#       <th>Year</th>
#       <th>Country</th>
#       <th>Disease</th>
#       <th>...</th>
#       <th>attr_env_medium</th>
#       <th>attr_isolate</th>
#       <th>attr_sex</th>
#       <th>Calculated Country</th>
#       <th>disease_name</th>
#       <th>classification_confidence</th>
#       <th>classification_reasoning</th>
#       <th>icd11_code</th>
#       <th>icd11_description</th>
#       <th>icd11_search_confidence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>13</th>
#       <td>UsykZolnik2020</td>
#       <td>you're good!</td>
#       <td>EmilySong</td>
#       <td>human</td>
#       <td>Vaginal</td>
#       <td>https://journals.plos.org/plospathogens/articl...</td>
#       <td>Cervicovaginal microbiome and natural history ...</td>
#       <td>2020</td>
#       <td>United States</td>
#       <td></td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>Cervical intraepithelial neoplasia</td>
#       <td>high</td>
#       <td>The study explicitly investigates the role of ...</td>
#       <td>GA15.7</td>
#       <td>Low grade squamous intraepithelial lesion of c...</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>ChunDo2021</td>
#       <td>you're good!</td>
#       <td>HarrisonGu</td>
#       <td>human</td>
#       <td>Nasal</td>
#       <td>https://www.jacionline.org/article/S0091-6749(...</td>
#       <td>The nasal microbiome, nasal transcriptome, and...</td>
#       <td>2021</td>
#       <td>United States</td>
#       <td></td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>Pet allergies</td>
#       <td>high</td>
#       <td>The title and abstract explicitly state that t...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>BaedeBarray2022</td>
#       <td>you're good!</td>
#       <td>HarrisonGu</td>
#       <td>human</td>
#       <td>Nasal</td>
#       <td>https://pmc.ncbi.nlm.nih.gov/articles/PMC9671894/</td>
#       <td>Nasal microbiome disruption and recovery after...</td>
#       <td>2022</td>
#       <td>France</td>
#       <td></td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>Not processed</td>
#       <td></td>
#       <td>Could not retrieve article details from PubMed.</td>
#       <td>Not processed</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>FazlollahiLee2018</td>
#       <td>you're good!</td>
#       <td>HarrisonGu</td>
#       <td>human</td>
#       <td>Nasal</td>
#       <td>https://pmc.ncbi.nlm.nih.gov/articles/PMC6123291/</td>
#       <td>The Nasal Microbiome in Asthma</td>
#       <td>2018</td>
#       <td>United States</td>
#       <td></td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>Asthma</td>
#       <td>high</td>
#       <td>The title, abstract, and methods section all e...</td>
#       <td>CA23</td>
#       <td>Asthma</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>IrizarChun2023</td>
#       <td>you're good!</td>
#       <td>HarrisonGu</td>
#       <td>human</td>
#       <td>Nasal</td>
#       <td>https://pmc.ncbi.nlm.nih.gov/articles/PMC9643606/</td>
#       <td>Examination of host genetic effects on nasal m...</td>
#       <td>2022</td>
#       <td>United States</td>
#       <td></td>
#       <td>...</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>Asthma</td>
#       <td>high</td>
#       <td>The abstract explicitly states that 'Genetic p...</td>
#       <td>CA23</td>
#       <td>Asthma</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# <p>5 rows × 66 columns</p>
# </div>

# %% [markdown]
# ### Step 4

# %%
# ==============================================================================
# STEP 4: PROCESS EACH ACCESSION CODE (MAIN FETCHING LOOP)
# ==============================================================================
new_results = []
print(f"\n--- Starting NCBI/CNGB Data Extraction for {len(new_rows_to_process)} new records (Pass 1) ---")

valid_new_rows = new_rows_to_process[new_rows_to_process.get("Has someone done this study?") != "Someone else did this study!"].copy()
print(f"Skipping {len(new_rows_to_process) - len(valid_new_rows)} records marked as done by someone else.")

if not valid_new_rows.empty:
    for index, row in valid_new_rows.iterrows():
        # The 'index' from iterrows() is the original index from main_data_sheet
        accession = row['AccessionCode'].strip()
        sra_details = get_sra_and_biosample_details(accession)

        if sra_details:
            # IMPORTANT: Store the original index with the results
            sra_details['original_index'] = index
            new_results.append(sra_details)

        print(f"  > Processed {index} accessions.")

print("\n--- Raw Data Extraction Complete ---")
# Out:
# --- Starting NCBI/CNGB Data Extraction for 1087 new records (Pass 1) ---
# Skipping 2 records marked as done by someone else.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 13 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 25 accessions.
# Skipping invalid or unsupported accession format: https://zenodo.org/records/6382657
#   > Processed 28 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 29 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 30 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 34 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 35 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 40 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 41 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 43 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 44 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 45 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 47 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 48 accessions.
# Skipping invalid or unsupported accession format: https://figshare.com/articles/dataset/The_international_sinonasal_microbiome_study_ISMS_Dataset/11871420
#   > Processed 51 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 53 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 57 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 61 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 65 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 66 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 67 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 68 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 72 accessions.
# Skipping invalid or unsupported accession format: https://zenodo.org/records/10403630
#   > Processed 73 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 75 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 77 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 86 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 87 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 88 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 89 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 92 accessions.
# Skipping invalid or unsupported accession format: HRA004429, CNP0003852
#   > Processed 97 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 98 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 100 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 101 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 105 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 106 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 108 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 109 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 111 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 112 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 113 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 115 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 118 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 121 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 122 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 125 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 127 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 128 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 130 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 131 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 134 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 135 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 137 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 139 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 140 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 144 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 145 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 146 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 148 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 155 accessions.
# Skipping invalid or unsupported accession format:
#   > Processed 162 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 164 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 165 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 166 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 167 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 168 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 169 accessions.
# Skipping invalid or unsupported accession format: mgm4504962.3
#   > Processed 170 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 173 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 175 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 176 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 177 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 180 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 184 accessions.
# Skipping invalid or unsupported accession format: CRA011157
#   > Processed 186 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 187 accessions.
# Skipping invalid or unsupported accession format: CRA006099
#   > Processed 190 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 193 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 195 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 196 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 197 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 201 accessions.
# Skipping invalid or unsupported accession format: CRA015579
#   > Processed 202 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 208 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 209 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 215 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 216 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 220 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 221 accessions.
# Skipping invalid or unsupported accession format: https://datadryad.org/dataset/doi:10.5061/dryad.cp8sr
#   > Processed 222 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 224 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 225 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 234 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 235 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 238 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 240 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 243 accessions.
# Skipping invalid or unsupported accession format: mgp16453,mgp16510,mgp16544,mgp16599,mgp16600
#   > Processed 249 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 253 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 254 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 255 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 256 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 257 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 258 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 262 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 264 accessions.
# Skipping invalid or unsupported accession format: mgp16453,mgp16510,mgp16544,mgp16599,mgp16600
#   > Processed 266 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 267 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 270 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 271 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 273 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 275 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 277 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 280 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 283 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 284 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 286 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 287 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 288 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 290 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 292 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 295 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 296 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 297 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 301 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 304 accessions.
# Skipping invalid or unsupported accession format: CRA002142
#   > Processed 305 accessions.
# Skipping invalid or unsupported accession format: OEP001718
#   > Processed 308 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 310 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 311 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 317 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 318 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 319 accessions.
# Skipping invalid or unsupported accession format: meta-analysis
#   > Processed 322 accessions.
# Skipping invalid or unsupported accession format:
#   > Processed 324 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 333 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 335 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 338 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 340 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 341 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 342 accessions.
# Skipping invalid or unsupported accession format: https://data.mendeley.com/datasets/mhvsdwcnf5/1
#   > Processed 347 accessions.
# Skipping invalid or unsupported accession format: HRA000020/EGAS00001004480
#   > Processed 351 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 353 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 354 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 358 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 359 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 361 accessions.
# Skipping invalid or unsupported accession format: Quiita id: 14433
#   > Processed 362 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 365 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 371 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 374 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 377 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 378 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 379 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 381 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 383 accessions.
# Skipping invalid or unsupported accession format: https://bioconductor.org/packages/release/data/experiment/html/curatedMetagenomicData.html
#   > Processed 386 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 387 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 391 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 392 accessions.
# Skipping invalid or unsupported accession format: https://www.immport.org/shared/study/SDY1182
#   > Processed 394 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 398 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 399 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 404 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 407 accessions.
# Skipping invalid or unsupported accession format: https://figshare.com/s/8c742fca1ec5e317324a
#   > Processed 411 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 414 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 415 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 419 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 421 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 423 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 425 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 426 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 431 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 433 accessions.
# Skipping invalid or unsupported accession format: https://figshare.com/s/e337e0b26af010885553?file=23411693
#   > Processed 434 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 435 accessions.
# Skipping invalid or unsupported accession format: OSD-630,OSD-572,OSD-573
#   > Processed 437 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 439 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 440 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 447 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 448 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 449 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 450 accessions.
# Skipping invalid or unsupported accession format: CP071512-CP071515
#   > Processed 458 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 459 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 461 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 462 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 466 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 470 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 472 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 476 accessions.
# Skipping invalid or unsupported accession format: CRA004468
#   > Processed 477 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 480 accessions.
# Skipping invalid or unsupported accession format: https://zenodo.org/records/10401639
#   > Processed 481 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 482 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 485 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 487 accessions.
# Skipping invalid or unsupported accession format: https://www.biosino.org/node/project/detail/OEP002914.
#   > Processed 489 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 491 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 492 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 494 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 495 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 496 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 500 accessions.
# Skipping invalid or unsupported accession format: https://figshare.com/s/623a1e47b4bed20459a7?file=7872040
#   > Processed 510 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 511 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 512 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 520 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 521 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 522 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 523 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 527 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 532 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 533 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 536 accessions.
# Skipping invalid or unsupported accession format: https://www.biosino.org/node/browse?keyword=OEX016816
#   > Processed 537 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 538 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 541 accessions.
# Skipping invalid or unsupported accession format: https://doi.org/10.6084/m9.figshare.16435185
#   > Processed 544 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 545 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 547 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 550 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 551 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 555 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 559 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 560 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 563 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 564 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 565 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 568 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 570 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 572 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 573 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 574 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 575 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 576 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 577 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 579 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 586 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 589 accessions.
# Skipping invalid or unsupported accession format: AJ968563-AJ968646
#   > Processed 592 accessions.
# Skipping invalid or unsupported accession format: SRA026959
#   > Processed 593 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 597 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 598 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 600 accessions.
# Skipping invalid or unsupported accession format: OEP000464
#   > Processed 602 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 603 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 609 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 610 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 615 accessions.
# Skipping invalid or unsupported accession format: https://ngdc.cncb.ac.cn/bioproject/browse/PRJCA024210
#   > Processed 617 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 619 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 621 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 622 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 624 accessions.
# Skipping invalid or unsupported accession format: https://ngdc.cncb.ac.cn/gsa/browse/CRA022432; https://ngdc.cncb.ac.cn/gsa-human/browse/HRA010166
#   > Processed 628 accessions.
# Skipping invalid or unsupported accession format: https://www.redjournal.org/cms/10.1016/j.ijrobp.2023.06.2515/attachment/40ecc133-1c66-4c57-9a05-ffcf17fdb249/mmc4.xlsx
#   > Processed 629 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 630 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 631 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 632 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 636 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 639 accessions.
# Skipping invalid or unsupported accession format: Qiita: 10532
#   > Processed 644 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 646 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 648 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 652 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 653 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 654 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 657 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 659 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 661 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 670 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 673 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 674 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 679 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 682 accessions.
# Skipping invalid or unsupported accession format: CRA012802
#   > Processed 689 accessions.
# Skipping invalid or unsupported accession format: mgm4567749.3
#   > Processed 690 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 692 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 694 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 697 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 699 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 703 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 705 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 708 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 712 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 713 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 717 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 720 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 721 accessions.
# Skipping invalid or unsupported accession format: EGAD00001004160
#   > Processed 723 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 728 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 735 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 736 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 737 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 741 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 742 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 745 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 749 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 750 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 752 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 755 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 756 accessions.
# Skipping invalid or unsupported accession format: 10.5281/zenodo.6366622
#   > Processed 757 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 760 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 761 accessions.
# Skipping invalid or unsupported accession format: 10.5281/zenodo.14722217
#   > Processed 763 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 765 accessions.
# Skipping invalid or unsupported accession format: CRA015747
#   > Processed 767 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 769 accessions.
# Skipping invalid or unsupported accession format: EGAD00001010142, EGAD00001010143, EGAD50000000050, EGAD00001007783
#   > Processed 773 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 776 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 778 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 782 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 783 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 784 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 789 accessions.
# Skipping invalid or unsupported accession format: GSE200969
#   > Processed 790 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 793 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 795 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 796 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 797 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 798 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 805 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 806 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 807 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 808 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 809 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 811 accessions.
# Skipping invalid or unsupported accession format: AB663494, AB663495, AB663496, AB663497, AB663498
#   > Processed 819 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 823 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 824 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 828 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 830 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 836 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 838 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 840 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 841 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 842 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 843 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 845 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 850 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 856 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 860 accessions.
# Skipping invalid or unsupported accession format: JF241944–JF260864 and HE605382–HE608150
#   > Processed 865 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 866 accessions.
# Skipping invalid or unsupported accession format: Qiita: 11666
#   > Processed 867 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 869 accessions.
# Skipping invalid or unsupported accession format: GSE2658
#   > Processed 872 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 874 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 875 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 876 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 878 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 879 accessions.
# Skipping invalid or unsupported accession format: GSE34439
#   > Processed 881 accessions.
# Skipping invalid or unsupported accession format: CRA004105
#   > Processed 882 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 885 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 886 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 887 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 888 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 892 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 895 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 902 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 906 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 909 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 912 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 913 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 914 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 915 accessions.
# Skipping invalid or unsupported accession format: CRA018760
#   > Processed 916 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 918 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 921 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 925 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 927 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 931 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 933 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 936 accessions.
# Skipping invalid or unsupported accession format: https://figshare.com/articles/dataset/Oral_Microbiota_in_Infants_Fed_a_Formula_Supplemented_with_Bovine_Milk_Fat_Globule_Membranes/3422962
#   > Processed 939 accessions.
# Skipping invalid or unsupported accession format: CRA021412
#   > Processed 942 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 946 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 948 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 949 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 950 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 953 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 955 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 956 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 958 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 959 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 964 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 965 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 966 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 967 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 968 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 969 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 970 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 972 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 973 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 974 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 975 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 976 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 977 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 978 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 979 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 981 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 983 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 984 accessions.
# Skipping invalid or unsupported accession format: HRA004928
#   > Processed 985 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 986 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 988 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 990 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 992 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 993 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 994 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 998 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1000 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1002 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1004 accessions.
# Skipping invalid or unsupported accession format: OEP002667
#   > Processed 1006 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1009 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1013 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1015 accessions.
# Skipping invalid or unsupported accession format: EGAC00001003433
#   > Processed 1016 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1018 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1023 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1031 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1032 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1034 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1035 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1039 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1040 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1043 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1044 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1045 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1046 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1047 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1048 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1052 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1059 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1062 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1063 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1067 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1068 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1069 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1072 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1073 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1074 accessions.
# Skipping invalid or unsupported accession format: HRA001244
#   > Processed 1075 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1077 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1079 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1080 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1081 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1082 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1090 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1091 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1092 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1094 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1098 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1105 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1106 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1109 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1114 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1115 accessions.
# Skipping invalid or unsupported accession format: mgp8654
#   > Processed 1116 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1117 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1118 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1119 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1120 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1121 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1122 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1124 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1134 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1136 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1137 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1139 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1140 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1141 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1143 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1144 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1146 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1148 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1150 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1152 accessions.
# Skipping invalid or unsupported accession format: CRA007901
#   > Processed 1154 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1155 accessions.
# Skipping invalid or unsupported accession format: https://data.mendeley.com/datasets/dnybvvshz2/1
#   > Processed 1157 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1159 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1160 accessions.
# Skipping invalid or unsupported accession format: https://qiita.ucsd.edu/study/description/15910
#   > Processed 1165 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1168 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1170 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1171 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1174 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1175 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1176 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1180 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1183 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1184 accessions.
# Skipping invalid or unsupported accession format: https://doi.org/10.5281/zenodo.4607309
#   > Processed 1187 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1188 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1191 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1194 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1196 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1198 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1201 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1202 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1203 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1204 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1205 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1207 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1211 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1215 accessions.
# Skipping invalid or unsupported accession format: mgp84098
#   > Processed 1216 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1217 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1220 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1222 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1223 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1224 accessions.
# Skipping invalid or unsupported accession format: 3
#   > Processed 1225 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1228 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1229 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1231 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1233 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1234 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1236 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1244 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1248 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1251 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1252 accessions.
# Skipping invalid or unsupported accession format: https://datadryad.org/dataset/doi:10.5061/dryad.sn02v6x60
#   > Processed 1253 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1254 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1256 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1257 accessions.
# Skipping invalid or unsupported accession format:
#   > Processed 1260 accessions.
# Skipping invalid or unsupported accession format: GSE52791
#   > Processed 1262 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1265 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1267 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1269 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1271 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1272 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1277 accessions.
# Skipping invalid or unsupported accession format: https://zenodo.org/records/5031783
#   > Processed 1288 accessions.
# Skipping invalid or unsupported accession format: n/a
#   > Processed 1291 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 1293 accessions.
# ...
#   > Fetching SRA metadata for batch 5...
#   > Fetching SRA metadata for batch 6...
#   > Fetching SRA metadata for batch 7...
#   > Fetching SRA metadata for batch 8...
#   > Fetching SRA metadata for batch 9...
#   > Fetching SRA metadata for batch 10...
#   > Fetching SRA metadata for batch 11...
#   > Fetching SRA metadata for batch 12...
#   > Fetching SRA metadata for batch 13...
#   > Fetching SRA metadata for batch 14...
#   > Fetching SRA metadata for batch 15...
#   > Fetching SRA metadata for batch 16...
#   > Fetching SRA metadata for batch 17...
#   > Fetching SRA metadata for batch 18...
#   > Fetching SRA metadata for batch 19...
#   > Fetching SRA metadata for batch 20...
#   > Fetching SRA metadata for batch 21...
#   > Fetching SRA metadata for batch 22...
#   > Fetching SRA metadata for batch 23...
#   > Fetching SRA metadata for batch 24...
#   > Fetching SRA metadata for batch 25...
#   > Fetching SRA metadata for batch 26...
#   > Fetching SRA metadata for batch 27...
#   > Fetching SRA metadata for batch 28...
#   > Fetching SRA metadata for batch 29...
#   > Fetching SRA metadata for batch 30...
#   > Fetching SRA metadata for batch 31...
#   > Fetching SRA metadata for batch 32...
#   > Fetching SRA metadata for batch 33...
#   > Fetching SRA metadata for batch 34...
#   > Fetching SRA metadata for batch 35...
#   > Fetching SRA metadata for batch 36...
#   > Fetching SRA metadata for batch 37...
#   > Fetching SRA metadata for batch 38...
#   > Fetching SRA metadata for batch 39...
#   > Fetching SRA metadata for batch 40...
#   > Fetching SRA metadata for batch 41...
#   > Fetching SRA metadata for batch 42...
#   > Fetching SRA metadata for batch 43...
#   > Fetching SRA metadata for batch 44...
#   > Fetching SRA metadata for batch 45...
#   > Fetching SRA metadata for batch 46...
#   > Fetching SRA metadata for batch 47...
#   > Fetching SRA metadata for batch 48...
#   > Fetching SRA metadata for batch 49...
#   > Fetching SRA metadata for batch 50...
#   > Fetching SRA metadata for batch 51...
#   > Fetching SRA metadata for batch 52...
#   > Fetching SRA metadata for batch 53...
#   > Fetching SRA metadata for batch 54...
#   > Fetching SRA metadata for batch 55...
#   > Fetching SRA metadata for batch 56...
#   > Fetching SRA metadata for batch 57...
#   > Fetching SRA metadata for batch 58...
#   > Fetching SRA metadata for batch 59...
#   > Fetching SRA metadata for batch 60...
#   > Fetching SRA metadata for batch 61...
#   > Fetching SRA metadata for batch 62...
#   > Fetching SRA metadata for batch 63...
#   > Fetching SRA metadata for batch 64...
#   > Fetching SRA metadata for batch 65...
#   > Fetching SRA metadata for batch 66...
#   > Fetching SRA metadata for batch 67...
#   > Fetching SRA metadata for batch 68...
#   > Fetching SRA metadata for batch 69...
#   > Fetching SRA metadata for batch 70...
#   > Fetching SRA metadata for batch 71...
#   > Fetching SRA metadata for batch 72...
#   > Fetching SRA metadata for batch 73...
#   > Fetching SRA metadata for batch 74...
#   > Fetching SRA metadata for batch 75...
#   > Fetching SRA metadata for batch 76...
#   > Fetching SRA metadata for batch 77...
#   > Fetching SRA metadata for batch 78...
#   > Fetching SRA metadata for batch 79...
#   > Fetching SRA metadata for batch 80...
#   > Fetching SRA metadata for batch 81...
#   > Fetching SRA metadata for batch 82...
#   > Fetching SRA metadata for batch 83...
#   > Fetching SRA metadata for batch 84...
#   > Fetching SRA metadata for batch 85...
#   > Fetching SRA metadata for batch 86...
#   > Fetching SRA metadata for batch 87...
#   > Fetching SRA metadata for batch 88...
#   > Fetching SRA metadata for batch 89...
#   > Fetching SRA metadata for batch 90...
#   > Fetching SRA metadata for batch 91...
#   > Fetching SRA metadata for batch 92...
#   > Fetching SRA metadata for batch 93...
#   > Fetching SRA metadata for batch 94...
#   > Fetching SRA metadata for batch 95...
#   > Fetching SRA metadata for batch 96...
#   > Found 9508 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA545312.
#   > Processed 2289 accessions.
# Fetching SRA data for PRJNA506988...
#   > Experiments found 195
#   > Fetching SRA metadata for batch 1...
#   > Found 195 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA506988.
#   > Processed 2290 accessions.
# Fetching SRA data for PRJNA906498...
#   > Experiments found 48
#   > Fetching SRA metadata for batch 1...
#   > Found 48 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA906498.
#   > Processed 2291 accessions.
# Fetching SRA data for PRJNA509675...
#   > Experiments found 106
#   > Fetching SRA metadata for batch 1...
#   > Found 25 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA509675.
#   > Processed 2292 accessions.
# Fetching SRA data for PRJNA508588...
#   > Experiments found 467
#   > Fetching SRA metadata for batch 1...
#   > Fetching SRA metadata for batch 2...
#   > Fetching SRA metadata for batch 3...
#   > Found 467 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA508588.
#   > Processed 2293 accessions.
# Fetching SRA data for PRJNA324129...
#   > Experiments found 269
#   > Fetching SRA metadata for batch 1...
#   > Fetching SRA metadata for batch 2...
#   > Found 107 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA324129.
#   > Processed 2294 accessions.
# Fetching SRA data for PRJEB27308...
#   > Experiments found 597
#   > Fetching SRA metadata for batch 1...
#   > Fetching SRA metadata for batch 2...
#   > Fetching SRA metadata for batch 3...
#   > Found 140 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJEB27308.
#   > Processed 2295 accessions.
# Fetching SRA data for PRJNA563061...
#   > Experiments found 15
#   > Fetching SRA metadata for batch 1...
#   > Found 15 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA563061.
#   > Processed 2296 accessions.
# Fetching NGDC data for PRJCA011493...
#   > Scraping for sample list: https://ngdc.cncb.ac.cn/bioproject/browse/PRJCA011493
#   > Found 150 unique BioSample accessions.
#   > Processing sample 150/150: SAMC869714
#   > Sample processing complete.
#   > Successfully processed PRJCA011493.
#   > Processed 2297 accessions.
# Fetching NGDC data for PRJCA023305...
#   > Scraping for sample list: https://ngdc.cncb.ac.cn/bioproject/browse/PRJCA023305
#   > Found 46 unique BioSample accessions.
#   > Processing sample 1/46: SAMC3411599  > An unexpected critical error occurred for PRJCA023305: 'NoneType' object has no attribute 'get'
#   > Processed 2298 accessions.
# Skipping invalid or unsupported accession format: GSE262065
#   > Processed 2299 accessions.
# Fetching SRA data for PRJNA545408...
#   > Experiments found 253
#   > Fetching SRA metadata for batch 1...
#   > Fetching SRA metadata for batch 2...
#   > Found 243 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA545408.
#   > Processed 2300 accessions.
# Skipping invalid or unsupported accession format: EU503541
#   > Processed 2301 accessions.
# Fetching SRA data for PRJNA1082502...
#   > Experiments found 152
#   > Fetching SRA metadata for batch 1...
#   > Found 152 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA1082502.
#   > Processed 2302 accessions.
# Fetching SRA data for PRJNA889354...
#   > Experiments found 32
#   > Fetching SRA metadata for batch 1...
#   > Found 32 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA889354.
#   > Processed 2303 accessions.
# Fetching SRA data for PRJNA400072...
#   > Experiments found 220
#   > Fetching SRA metadata for batch 1...
#   > Fetching SRA metadata for batch 2...
#   > Found 220 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA400072.
#   > Processed 2304 accessions.
# Fetching SRA data for PRJEB31971...
#   > Experiments found 7
#   > Fetching SRA metadata for batch 1...
#   > Found 5 unique BioSamples. Fetching all raw attributes...
#   > WARNING: Received status 429. Retrying in 5 seconds...
#   > Successfully processed PRJEB31971.
#   > Processed 2305 accessions.
# Fetching SRA data for PRJNA818684....
#   > Experiments found 32
#   > Fetching SRA metadata for batch 1...
#   > Found 2 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA818684..
#   > Processed 2306 accessions.
# Fetching SRA data for PRJNA540704...
#   > Experiments found 325
#   > Fetching SRA metadata for batch 1...
#   > Fetching SRA metadata for batch 2...
#   > Found 325 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA540704.
#   > Processed 2307 accessions.
# Skipping invalid or unsupported accession format: MK059754-MK059772.
#   > Processed 2308 accessions.
# Skipping invalid or unsupported accession format: PXD026999
#   > Processed 2309 accessions.
# Skipping invalid or unsupported accession format:
#   > Processed 2310 accessions.
# Skipping invalid or unsupported accession format:
#   > Processed 2311 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 2312 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 2313 accessions.
# Fetching SRA data for PRJNA782492...
#   > Experiments found 0
#   > No experiments found for PRJNA782492.
#   > Processed 2314 accessions.
# Fetching SRA data for PRJNA1197754...
#   > Experiments found 63
#   > Fetching SRA metadata for batch 1...
#   > WARNING: Received status 429. Retrying in 5 seconds...
#   > Found 63 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA1197754.
#   > Processed 2315 accessions.
# Skipping invalid or unsupported accession format: N/A
#   > Processed 2316 accessions.
# Fetching SRA data for PRJNA913682...
#   > Experiments found 115
#   > Fetching SRA metadata for batch 1...
#   > Found 115 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA913682.
#   > Processed 2317 accessions.
# Fetching SRA data for PRJNA910923...
#   > Experiments found 26
#   > Fetching SRA metadata for batch 1...
#   > Found 26 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA910923.
#   > Processed 2318 accessions.
# Skipping invalid or unsupported accession format: None
#   > Processed 2319 accessions.
# Fetching SRA data for PRJNA1046251...
#   > Experiments found 12
#   > Fetching SRA metadata for batch 1...
#   > Found 12 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA1046251.
#   > Processed 2320 accessions.
# Fetching SRA data for PRJEB52380...
#   > Experiments found 179
#   > Fetching SRA metadata for batch 1...
#   > Found 178 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJEB52380.
#   > Processed 2321 accessions.
# Fetching SRA data for PRJNA700829...
#   > Experiments found 60
#   > Fetching SRA metadata for batch 1...
#   > Found 60 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA700829.
#   > Processed 2322 accessions.
# Skipping invalid or unsupported accession format: Many (huge meta analysis)
#   > Processed 2323 accessions.
# Fetching SRA data for PRJNA1147664...
#   > Experiments found 93
#   > Fetching SRA metadata for batch 1...
#   > Found 93 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA1147664.
#   > Processed 2324 accessions.
# Skipping invalid or unsupported accession format:
#   > Processed 2325 accessions.
# Fetching SRA data for PRJNA1253148...
#   > Experiments found 24
#   > Fetching SRA metadata for batch 1...
#   > Found 24 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA1253148.
#   > Processed 2326 accessions.
# Fetching SRA data for PRJNA1188328...
#   > Experiments found 12
#   > Fetching SRA metadata for batch 1...
#   > Found 12 unique BioSamples. Fetching all raw attributes...
#   > WARNING: Received status 429. Retrying in 5 seconds...
#   > Successfully processed PRJNA1188328.
#   > Processed 2327 accessions.
# Fetching CNGBdb data for CNP0004236, CNP0005937...
#   > Connecting to FTP server: ftp2.cngb.org
#   > An unexpected critical error occurred for CNP0004236, CNP0005937: 550 Failed to change directory.
#   > FTP connection closed.
#   > Processed 2328 accessions.
# Fetching SRA data for PRJNA1265886...
#   > Experiments found 283
#   > Fetching SRA metadata for batch 1...
#   > Fetching SRA metadata for batch 2...
#   > Found 283 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA1265886.
#   > Processed 2329 accessions.
# Fetching CNGBdb data for CNP0004236....
#   > Connecting to FTP server: ftp2.cngb.org
#   > An unexpected critical error occurred for CNP0004236.: 550 Failed to change directory.
#   > FTP connection closed.
#   > Processed 2330 accessions.
# Skipping invalid or unsupported accession format: BioSample IDs =SAMN08684029-SAMN08684111
#   > Processed 2331 accessions.
# Fetching SRA data for PRJEB34536...
#   > Experiments found 91
#   > Fetching SRA metadata for batch 1...
#   > Found 91 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJEB34536.
#   > Processed 2332 accessions.
# Fetching CNGBdb data for CNP0003685...
#   > Connecting to FTP server: ftp2.cngb.org
#   > Found 3 files in directory.
#   > ERROR: Could not find both experiment and sample .tsv files in the directory.
#   > FTP connection closed.
#   > Processed 2333 accessions.
# Fetching SRA data for PRJNA1210164...
#   > Experiments found 0
#   > No experiments found for PRJNA1210164.
#   > Processed 2334 accessions.
# Fetching SRA data for PRJEB52754...
#   > Experiments found 136
#   > Fetching SRA metadata for batch 1...
#   > Found 68 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJEB52754.
#   > Processed 2335 accessions.
# Fetching SRA data for SRR31160755-SRR31160844...
#   > Experiments found 0
#   > No experiments found for SRR31160755-SRR31160844.
#   > Processed 2336 accessions.
# Fetching SRA data for PRJNA703762...
#   > Experiments found 116
#   > Fetching SRA metadata for batch 1...
#   > Found 116 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA703762.
#   > Processed 2337 accessions.
# Fetching SRA data for PRJNA1185457...
#   > Experiments found 19
#   > Fetching SRA metadata for batch 1...
#   > Found 19 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA1185457.
#   > Processed 2338 accessions.
# Fetching SRA data for PRJNA1146994...
#   > Experiments found 0
#   > No experiments found for PRJNA1146994.
#   > Processed 2339 accessions.
# Skipping invalid or unsupported accession format: CRA015070
#   > Processed 2340 accessions.
# Fetching SRA data for PRJNA1143938...
#   > Experiments found 401
#   > Fetching SRA metadata for batch 1...
#   > Fetching SRA metadata for batch 2...
#   > Fetching SRA metadata for batch 3...
#   > Found 401 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA1143938.
#   > Processed 2341 accessions.
# Fetching SRA data for PRJNA910312...
#   > Experiments found 210
#   > Fetching SRA metadata for batch 1...
#   > Fetching SRA metadata for batch 2...
#   > Found 210 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA910312.
#   > Processed 2342 accessions.
# Fetching SRA data for PRJNA1203073...
#   > Experiments found 9
#   > Fetching SRA metadata for batch 1...
#   > Found 9 unique BioSamples. Fetching all raw attributes...
#   > WARNING: Received status 429. Retrying in 5 seconds...
#   > Successfully processed PRJNA1203073.
#   > Processed 2343 accessions.
# Fetching SRA data for PRJNA773113...
#   > Experiments found 66
#   > Fetching SRA metadata for batch 1...
#   > Found 66 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA773113.
#   > Processed 2344 accessions.
# Fetching SRA data for PRJNA1210767...
#   > Experiments found 36
#   > Fetching SRA metadata for batch 1...
#   > Found 36 unique BioSamples. Fetching all raw attributes...
#   > Successfully processed PRJNA1210767.
#   > Processed 2345 accessions.
# Fetching SRA data for PRJNA1141956...
#   > Experiments found 0
#   > No experiments found for PRJNA1141956.
#   > Processed 2346 accessions.
#
# --- Raw Data Extraction Complete ---

# %% [markdown]
# ### Step 5

# %%
# ==============================================================================
# STEP 5: POST-PROCESSING AND GLOBAL NORMALIZATION (PASS 2)
# ==============================================================================
print("\n--- Starting Global Post-Processing (Pass 2) ---")

if not new_results:
    print("No new data was processed. Final output will match the original sheet.")
    # If there are no new results, we can skip straight to the end
    results_df = pd.DataFrame() # Create an empty DataFrame
else:
    print("\n--- Starting Global Post-Processing on new data (Pass 2) ---")
    results_df = pd.DataFrame(new_results)

    # --- Part A: Determine Top 10 Attribute Keys ---
    if 'BioSampleAttributes' in results_df.columns:
        print("  > Aggregating BioSample attributes across all new projects...")
        global_key_counts = defaultdict(int)
        # Ensure the column is treated as dictionaries
        results_df['BioSampleAttributes'] = results_df['BioSampleAttributes'].apply(lambda x: x if isinstance(x, dict) else {})

        for attr_dict in results_df['BioSampleAttributes']:
            for key in attr_dict.keys():
                global_key_counts[key] += 1

        # Get existing "attr_" columns from the original sheet for the new rows
        existing_attr_columns = [col for col in new_rows_to_process.columns if col.startswith('attr_')]
        existing_attr_keys = [col.replace('attr_', '') for col in existing_attr_columns]


        # Determine which keys to process (either top 10 new or all existing)
        if existing_attr_columns:
            print("  > Existing 'attr_' columns found. Filling these columns.")
            keys_to_process = existing_attr_keys
        else:
            print("  > No existing 'attr_' columns found. Determining top 10 from new data.")
            keys_to_process = sorted(global_key_counts, key=global_key_counts.get, reverse=True)[:10]

        print(f"  > Keys to process: {keys_to_process}")

        for key in keys_to_process:
            col_name = f"attr_{key.replace(' ', '_').lower()}"
            # If the column exists, update it; otherwise, create it
            if col_name in results_df.columns and existing_attr_columns:
                 print(f"  > Filling existing column: {col_name}")
                 results_df[col_name] = results_df['BioSampleAttributes'].apply(
                    lambda attr_dict: '; '.join(attr_dict.get(key, []))
                 )
            else:
                print(f"  > Creating new column: {col_name}")
                results_df[col_name] = results_df['BioSampleAttributes'].apply(
                    lambda attr_dict: '; '.join(attr_dict.get(key, []))
                )
        results_df = results_df.drop(columns=['BioSampleAttributes'])

    # --- Part B: Normalize Host Column Using LLM ---
    if 'SRA Host' in results_df.columns:
        print("  > Normalizing 'SRA Host' column with LLM...")
        llm = LLMNormalizer()
        if llm.model:
            all_raw_hosts = set()
            for host_string in results_df['SRA Host'].dropna().astype(str):
                for host in host_string.split('; '):
                    if host: all_raw_hosts.add(host)
            final_host_normalization_map = llm.create_host_normalization_map(list(all_raw_hosts))
            if final_host_normalization_map:
                print(f"  > Created normalization map for {len(final_host_normalization_map)} unique host values.")
                def apply_normalization(host_string):
                    if not isinstance(host_string, str) or not host_string: return ''
                    hosts = host_string.split('; ')
                    normalized_values = {final_host_normalization_map.get(h.strip(), h.strip()) for h in hosts}
                    final_hosts = sorted([host for host in normalized_values if host is not None])
                    return '; '.join(final_hosts)
                results_df['SRA Host'] = results_df['SRA Host'].apply(apply_normalization)
                print("  > 'SRA Host' column normalized.")

# --- Part C (in this step): Set the index for joining ---
# This is critical for the next step.
if not results_df.empty:
    results_df.set_index('original_index', inplace=True)
# Out:
# --- Starting Global Post-Processing (Pass 2) ---
#
# --- Starting Global Post-Processing on new data (Pass 2) ---
#   > Aggregating BioSample attributes across all new projects...
#   > Existing 'attr_' columns found. Filling these columns.
#   > Keys to process: ['geo_loc_name', 'lat_lon', 'host', 'isolation_source', 'env_broad_scale', 'env_local_scale', 'env_medium', 'isolate', 'sex']
#   > Creating new column: attr_geo_loc_name
#   > Creating new column: attr_lat_lon
#   > Creating new column: attr_host
#   > Creating new column: attr_isolation_source
#   > Creating new column: attr_env_broad_scale
#   > Creating new column: attr_env_local_scale
#   > Creating new column: attr_env_medium
#   > Creating new column: attr_isolate
#   > Creating new column: attr_sex
#   > Normalizing 'SRA Host' column with LLM...
# LLM Normalizer initialized successfully.
#   > Created normalization map for 515 unique host values.
#   > 'SRA Host' column normalized.

# %%
# ==============================================================================
# STEP 6: CREATE FINAL MERGED OUTPUT
# ==============================================================================
print("\n--- Coalescing new data into the main sheet ---")

# Start with a direct copy of the original data
final_output_df = main_data_sheet.copy()

if not results_df.empty:
    # The `results_df` index was set to 'original_index' in Step 5.
    # The .update() method aligns on the index and overwrites existing
    # values in `final_output_df` with new data from `results_df`.
    # This acts as a "coalesce," filling in the processed data perfectly.
    # It only affects rows and columns that are present in `results_df`.
    final_output_df.update(results_df)

# Final cleanup of any remaining nulls or placeholder text
final_output_df.fillna('', inplace=True)
final_output_df.replace(['N/A', 'null'], '', inplace=True)

print(f"Final DataFrame created with {len(final_output_df)} rows.")
display(final_output_df.head())

# Save the final file
final_output_df.to_csv('final_output.csv', index=False)
print("Saved final data to 'final_output.csv'")
# Out:
# --- Coalescing new data into the main sheet ---
# Final DataFrame created with 2347 rows.
#   Author1Author2name (LastName1LastName2) Has someone done this study?  \
# 0                            ZhangLiu2020                 you're good!
# 1               Lev-SagieGoldman-Wohl2019                 you're good!
# 2                          BaldiBraat2024                 you're good!
# 3                        HosangCanals2022                 you're good!
# 4                             XiaoCai2022                 you're good!
#
#           YourName   Host Environment  \
# 0  SamuelDegregori  human        Oral
# 1        EmilySong  human     Vaginal
# 2   SolanaCallaway  human         Gut
# 3       VictoriaXu  human   Pulmonary
# 4     AnjaliVinodh  human   Pulmonary
#
#                                            StudyLink  \
# 0  https://pmc.ncbi.nlm.nih.gov/articles/pmid/320...
# 1  https://www.nature.com/articles/s41591-019-060...
# 2          https://pubmed.ncbi.nlm.nih.gov/39367018/
# 3  https://www.nature.com/articles/s41586-022-044...
# 4  https://pmc.ncbi.nlm.nih.gov/articles/PMC88654...
#
#                                           StudyTitle  Year     Country  \
# 0  The Oral Microbiota May Have Influence on Oral...  2020       China
# 1  Vaginal microbiome transplantation in women wi...  2019      Israel
# 2  Effects of iron supplements and iron-containin...  2024  Bangladesh
# 3   The lung microbiome regulates brain autoimmunity  2022     Germany
# 4  Insights into the Unique Lung Microbiota Profi...  2022       China
#
#   Disease  ... attr_env_medium attr_isolate attr_sex Calculated Country  \
# 0          ...                                                    China
# 1          ...
# 2          ...                                               Bangladesh
# 3          ...                                                  Germany
# 4          ...       BAL; Swab                                    China
#
#           disease_name classification_confidence  \
# 0          Oral cancer                      high
# 1  Bacterial vaginosis                      high
# 2               Anemia                      high
# 3   Multiple sclerosis                      high
# 4   Multiple sclerosis                      high
#
#                             classification_reasoning icd11_code  \
# 0  The title, abstract, and methods section expli...       2B6E
# 1  The title and abstract explicitly state that t...
# 2  The abstract explicitly states that anemia is ...
# 3  The abstract explicitly states that the study ...       8A40
# 4  The abstract explicitly states that the resear...       8A40
#
#                                    icd11_description icd11_search_confidence
# 0  Malignant neoplasms of other or ill-defined si...                    high
# 1
# 2            Anaemias or other erythrocyte disorders
# 3                                 Multiple sclerosis
# 4                                 Multiple sclerosis                    high
#
# [5 rows x 66 columns]
# Saved final data to 'final_output.csv'

# %%
# ==============================================================================
# ONE-TIME SCRIPT TO MERGE EXISTING PROCESSED FILE WITH MAIN SHEET
# ==============================================================================
import pandas as pd
from google.colab import auth
import gspread
from google.auth import default

print("--- Starting one-time merge process ---")

# --- Authenticate and Load Google Sheet ---
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

print("Loading data from Google Sheet...")
spreadsheet_url = 'https://docs.google.com/spreadsheets/d/1tBjpV_GoXIjx4_3o73Qml0h-BzFBZTD5bc3QHx1l1_4'
spreadsheet = gc.open_by_url(spreadsheet_url)
worksheet = spreadsheet.worksheet("Main Data Sheet")
all_values = worksheet.get_all_values()
header = all_values[1]
data_rows = all_values[2:]
main_data_sheet = pd.DataFrame(data_rows, columns=header)
print(f"Loaded {len(main_data_sheet)} records from Google Sheet.")

# --- Load and Prepare Processed Data ---
PROCESSED_FILE = 'all_rows.csv'
try:
    print(f"Loading data from {PROCESSED_FILE}...")
    processed_df = pd.read_csv(PROCESSED_FILE)

    # --- Define the columns you want to merge from the processed file ---
    columns_to_merge = [
        'AccessionCode',
        'Number of Experiments',
        'All Experiments IDs',
        'SRA Name',
        'Library Name',
        'Instrument Name',
        'Sample Title',
        'BioSample Accession',
        'SRA Host',
        'All Attribute Keys',
        'attr_geo_loc_name',
        'attr_lat_lon',
        'attr_host',
        'attr_isolation_source',
        'attr_env_broad_scale',
        'attr_env_local_scale',
        'attr_env_medium',
        'attr_isolate',
        'attr_sex'
    ]

    # Ensure all desired columns exist in the DataFrame, adding them if they don't
    for col in columns_to_merge:
        if col not in processed_df.columns:
            processed_df[col] = '' # Add missing columns as blank

    # Select only the columns we want to merge
    processed_df_to_merge = processed_df[columns_to_merge]

    # CRITICAL: Drop duplicates based on 'AccessionCode' to ensure a clean merge
    processed_df_to_merge.drop_duplicates(subset=['AccessionCode'], inplace=True)
    print(f"Prepared {len(processed_df_to_merge)} unique processed records for merging.")

    # --- Perform the Merge ---
    # Use a left merge to keep all rows from the original sheet
    print("Merging dataframes based on 'AccessionCode'...")
    final_merged_df = pd.merge(main_data_sheet, processed_df_to_merge, on='AccessionCode', how='left')
    print(f"New Lengtgh {len(final_merged_df)}")
    # --- Final Cleanup and Save ---
    final_merged_df.fillna('', inplace=True)
    if len(final_merged_df) == len(main_data_sheet):
      final_merged_df.to_csv('one_time_merge_result.csv', index=False)
    else:
      print("Issue with merge")

    print("\n--- Merge Complete ---")
    print("Saved final merged data to 'one_time_merge_result.csv'")
    # display(final_merged_df.head())

except FileNotFoundError:
    print(f"ERROR: The file '{PROCESSED_FILE}' was not found. Cannot perform merge.")
# Out:
# --- Starting one-time merge process ---
# Loading data from Google Sheet...
# Loaded 2251 records from Google Sheet.
# Loading data from all_rows.csv...
# /tmp/ipython-input-41-3311301256.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   processed_df_to_merge.drop_duplicates(subset=['AccessionCode'], inplace=True)
# /tmp/ipython-input-41-3311301256.py:73: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   final_merged_df.fillna('', inplace=True)
# Prepared 1130 unique processed records for merging.
# Merging dataframes based on 'AccessionCode'...
# New Lengtgh 2251
#
# --- Merge Complete ---
# Saved final merged data to 'one_time_merge_result.csv'
